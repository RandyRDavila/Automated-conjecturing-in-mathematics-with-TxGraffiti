# %% [markdown]
# # Breast Cancer Data Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/breast_cancer.ipynb)
#
# ## Introduction
#
# This notebook applies the TxGraffiti algorithm to generate conjectures on the famous breast cancer dataset. The dataset is commonly used in machine learning for binary classification tasks and contains various features related to breast cancer tumors.
#
# ## Dataset
#
# The dataset consists of breast cancer tumor data and includes various numerical properties such as:
# - **Mean Radius**: The mean of distances from the center to points on the perimeter.
# - **Mean Texture**: The standard deviation of gray-scale values.
# - **Mean Perimeter**: The perimeter of the tumor.
# - **Mean Area**: The area of the tumor.
# - **Mean Smoothness**: The local variation in radius lengths.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of breast cancer tumors.
# - Identify significant relationships and patterns in tumor properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to load the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Discover new insights into breast cancer tumor properties with TxGraffiti.
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="tumor"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="C"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="C"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Load the breast cancer dataset
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

# Define boolean properties based on some thresholds
df['high_mean_radius'] = df['mean radius'] > df['mean radius'].median()
df['high_mean_texture'] = df['mean texture'] > df['mean texture'].median()
df['high_mean_perimeter'] = df['mean perimeter'] > df['mean perimeter'].median()
df['high_mean_area'] = df['mean area'] > df['mean area'].median()
df['high_mean_smoothness'] = df['mean smoothness'] > df['mean smoothness'].median()

# Define the targets, invariants, and properties
targets = ["mean radius", "mean texture", "mean perimeter", "mean area", "mean smoothness"]
invariants = ["mean radius", "mean texture", "mean perimeter", "mean area", "mean smoothness"]
properties = ["high_mean_radius", "high_mean_texture", "high_mean_perimeter", "high_mean_area", "high_mean_smoothness"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/326af3276fd64c9f9486f9b51e3070d3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/326af3276fd64c9f9486f9b51e3070d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 574 COLUMNS
# At line 1715 RHS
# At line 2285 BOUNDS
# At line 2288 ENDATA
# Problem MODEL has 569 rows, 2 columns and 1138 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 479 (-90) rows, 2 (0) columns and 958 (-180) elements
# 0  Obj 0 Primal inf 1591.6156 (479) Dual inf 35.243143 (2) w.o. free dual inf (0)
# 3  Obj 15953.333
# Optimal - objective value 15953.333
# After Postsolve, objective 15953.333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15953.33331 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bac37be79fee45f89eda4e1b5f581eec-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bac37be79fee45f89eda4e1b5f581eec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 259 (-25) rows, 2 (0) columns and 518 (-50) elements
# 0  Obj 0 Primal inf 222.79424 (259) Dual inf 87.519598 (2) w.o. free dual inf (0)
# 2  Obj 7983.24
# 2  Obj 1.3964e+13 Primal inf 4.0736304e+11 (82) Dual inf 9.8457467e+14 (2) w.o. free dual inf (1)
# 3  Obj 7933.8289
# Optimal - objective value 7933.8289
# After Postsolve, objective 7933.8289, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7933.828923 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6504d7e3f7674ca5a55a18992077754c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6504d7e3f7674ca5a55a18992077754c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 243 (-41) rows, 2 (0) columns and 486 (-82) elements
# 0  Obj 0 Primal inf 168.92969 (243) Dual inf 117.9467 (2) w.o. free dual inf (0)
# 4  Obj 7740.685
# Optimal - objective value 7740.685
# After Postsolve, objective 7740.685, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7740.685 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f7745e1fba4d4804a423fd81d8c9cef4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f7745e1fba4d4804a423fd81d8c9cef4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 259 (-25) rows, 2 (0) columns and 518 (-50) elements
# 0  Obj 0 Primal inf 222.70212 (259) Dual inf 87.512298 (2) w.o. free dual inf (0)
# 2  Obj 7983.24
# 2  Obj 1.394575e+13 Primal inf 4.039401e+11 (82) Dual inf 9.831918e+14 (2) w.o. free dual inf (1)
# 3  Obj 7933.8935
# Optimal - objective value 7933.8935
# After Postsolve, objective 7933.8935, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7933.8935 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ddd089645152490081eb38b3a72e3e1c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ddd089645152490081eb38b3a72e3e1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 258 (-26) rows, 2 (0) columns and 516 (-52) elements
# 0  Obj 0 Primal inf 222.01738 (258) Dual inf 87.502998 (2) w.o. free dual inf (0)
# 2  Obj 7983.24
# 2  Obj 1.39225e+13 Primal inf 4.0580552e+11 (82) Dual inf 9.8394543e+14 (2) w.o. free dual inf (1)
# 3  Obj 7933.9758
# Optimal - objective value 7933.9758
# After Postsolve, objective 7933.9758, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7933.975769 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4ed8353b48b8493d8de8d75325fa01d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4ed8353b48b8493d8de8d75325fa01d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 261 (-23) rows, 2 (0) columns and 522 (-46) elements
# 0  Obj 0 Primal inf 888.15859 (261) Dual inf 17.561195 (2) w.o. free dual inf (0)
# 3  Obj 7964.2783
# Optimal - objective value 7964.2783
# After Postsolve, objective 7964.2783, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7964.278269 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d1a0a5009b5542cea47b70ade9587d25-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d1a0a5009b5542cea47b70ade9587d25-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# At line 745 BOUNDS
# At line 748 ENDATA
# Problem MODEL has 184 rows, 2 columns and 368 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 167 (-17) rows, 2 (0) columns and 334 (-34) elements
# 0  Obj 0 Primal inf 129.92567 (167) Dual inf 76.744798 (2) w.o. free dual inf (0)
# 4  Obj 5016.5855
# Optimal - objective value 5016.5855
# After Postsolve, objective 5016.5855, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5016.585455 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1e7f712761654383a2d599c3fefb1f18-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1e7f712761654383a2d599c3fefb1f18-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 283 COLUMNS
# At line 842 RHS
# At line 1121 BOUNDS
# At line 1124 ENDATA
# Problem MODEL has 278 rows, 2 columns and 556 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 254 (-24) rows, 2 (0) columns and 508 (-48) elements
# 0  Obj 0 Primal inf 219.18622 (254) Dual inf 85.727598 (2) w.o. free dual inf (0)
# 2  Obj 7814.58
# 2  Obj 1.38115e+13 Primal inf 3.9515053e+11 (80) Dual inf 9.5964081e+14 (2) w.o. free dual inf (1)
# 3  Obj 7765.7085
# Optimal - objective value 7765.7085
# After Postsolve, objective 7765.7085, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7765.708538 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bf17460c540240e5a64a1dff5314d821-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bf17460c540240e5a64a1dff5314d821-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 287 COLUMNS
# At line 854 RHS
# At line 1137 BOUNDS
# At line 1140 ENDATA
# Problem MODEL has 282 rows, 2 columns and 564 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 257 (-25) rows, 2 (0) columns and 514 (-50) elements
# 0  Obj 0 Primal inf 221.11833 (257) Dual inf 86.983898 (2) w.o. free dual inf (0)
# 2  Obj 7927.02
# 2  Obj 1.406725e+13 Primal inf 3.9952164e+11 (81) Dual inf 9.7140674e+14 (2) w.o. free dual inf (1)
# 3  Obj 7877.2436
# Optimal - objective value 7877.2436
# After Postsolve, objective 7877.2436, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7877.243577 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1a2a5c8432f04eab965b6326f0d3736a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1a2a5c8432f04eab965b6326f0d3736a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 162 COLUMNS
# At line 479 RHS
# At line 637 BOUNDS
# At line 640 ENDATA
# Problem MODEL has 157 rows, 2 columns and 314 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 151 (-6) rows, 2 (0) columns and 302 (-12) elements
# 0  Obj 0 Primal inf 132.78888 (151) Dual inf 48.549498 (2) w.o. free dual inf (0)
# 2  Obj 4413.27
# 2  Obj 8.1375e+12 Primal inf 2.3836583e+11 (45) Dual inf 5.4629979e+14 (2) w.o. free dual inf (1)
# 3  Obj 4384.4758
# Optimal - objective value 4384.4758
# After Postsolve, objective 4384.4758, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4384.475769 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e987941e316c492a908c691acb9239b6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e987941e316c492a908c691acb9239b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 190 COLUMNS
# At line 563 RHS
# At line 749 BOUNDS
# At line 752 ENDATA
# Problem MODEL has 185 rows, 2 columns and 370 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 167 (-18) rows, 2 (0) columns and 334 (-36) elements
# 0  Obj 0 Primal inf 129.97383 (167) Dual inf 77.086998 (2) w.o. free dual inf (0)
# 4  Obj 5043.5091
# Optimal - objective value 5043.5091
# After Postsolve, objective 5043.5091, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5043.509091 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b9c936fe826f430298e5751c7278957f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b9c936fe826f430298e5751c7278957f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# At line 745 BOUNDS
# At line 748 ENDATA
# Problem MODEL has 184 rows, 2 columns and 368 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 167 (-17) rows, 2 (0) columns and 334 (-34) elements
# 0  Obj 0 Primal inf 129.92567 (167) Dual inf 76.744798 (2) w.o. free dual inf (0)
# 4  Obj 5016.5855
# Optimal - objective value 5016.5855
# After Postsolve, objective 5016.5855, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5016.585455 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/53ebd4a9472945ff9b1533e47d9ca604-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/53ebd4a9472945ff9b1533e47d9ca604-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 146 COLUMNS
# At line 431 RHS
# At line 573 BOUNDS
# At line 576 ENDATA
# Problem MODEL has 141 rows, 2 columns and 282 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 133 (-8) rows, 2 (0) columns and 266 (-16) elements
# 0  Obj 0 Primal inf 96.621571 (133) Dual inf 58.318598 (2) w.o. free dual inf (0)
# 4  Obj 3841.9982
# Optimal - objective value 3841.9982
# After Postsolve, objective 3841.9982, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3841.998182 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/15179d39c73c45a6a101279dcb1dbb94-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/15179d39c73c45a6a101279dcb1dbb94-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 281 COLUMNS
# At line 836 RHS
# At line 1113 BOUNDS
# At line 1116 ENDATA
# Problem MODEL has 276 rows, 2 columns and 552 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 252 (-24) rows, 2 (0) columns and 504 (-48) elements
# 0  Obj 0 Primal inf 217.51032 (252) Dual inf 85.191898 (2) w.o. free dual inf (0)
# 2  Obj 7758.36
# 2  Obj 1.391475e+13 Primal inf 3.8730913e+11 (79) Dual inf 9.4647289e+14 (2) w.o. free dual inf (1)
# 3  Obj 7709.1232
# Optimal - objective value 7709.1232
# After Postsolve, objective 7709.1232, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7709.123192 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/255668a9706941d3adf477582e20a825-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/255668a9706941d3adf477582e20a825-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 167 COLUMNS
# At line 494 RHS
# At line 657 BOUNDS
# At line 660 ENDATA
# Problem MODEL has 162 rows, 2 columns and 324 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 156 (-6) rows, 2 (0) columns and 312 (-12) elements
# 0  Obj 0 Primal inf 136.30478 (156) Dual inf 50.029098 (2) w.o. free dual inf (0)
# 2  Obj 4553.82
# 2  Obj 8.23025e+12 Primal inf 2.471554e+11 (47) Dual inf 5.6985078e+14 (2) w.o. free dual inf (1)
# 3  Obj 4524.6976
# Optimal - objective value 4524.6976
# After Postsolve, objective 4524.6976, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4524.697577 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c7e087e14918495b9f48c0349fcb55e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c7e087e14918495b9f48c0349fcb55e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 149 (-6) rows, 2 (0) columns and 298 (-12) elements
# 0  Obj 0 Primal inf 131.11298 (149) Dual inf 48.013798 (2) w.o. free dual inf (0)
# 2  Obj 4357.05
# 2  Obj 8.24075e+12 Primal inf 2.3052443e+11 (44) Dual inf 5.3313187e+14 (2) w.o. free dual inf (1)
# 3  Obj 4327.8904
# Optimal - objective value 4327.8904
# After Postsolve, objective 4327.8904, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4327.890423 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/19a22738c3814195adc00552bb4abf2f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/19a22738c3814195adc00552bb4abf2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 186 COLUMNS
# At line 551 RHS
# At line 733 BOUNDS
# At line 736 ENDATA
# Problem MODEL has 181 rows, 2 columns and 362 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 164 (-17) rows, 2 (0) columns and 328 (-34) elements
# 0  Obj 0 Primal inf 128.14158 (164) Dual inf 75.484498 (2) w.o. free dual inf (0)
# 4  Obj 4934.7523
# Optimal - objective value 4934.7523
# After Postsolve, objective 4934.7523, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4934.752273 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ea6e00f3bff74545aa45a4b9c6c94b49-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ea6e00f3bff74545aa45a4b9c6c94b49-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# At line 745 BOUNDS
# At line 748 ENDATA
# Problem MODEL has 184 rows, 2 columns and 368 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 167 (-17) rows, 2 (0) columns and 334 (-34) elements
# 0  Obj 0 Primal inf 129.92567 (167) Dual inf 76.744798 (2) w.o. free dual inf (0)
# 4  Obj 5016.5855
# Optimal - objective value 5016.5855
# After Postsolve, objective 5016.5855, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5016.585455 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/409846e3a59749d6ae516c3e58c5eced-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/409846e3a59749d6ae516c3e58c5eced-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 108 COLUMNS
# At line 317 RHS
# At line 421 BOUNDS
# At line 424 ENDATA
# Problem MODEL has 103 rows, 2 columns and 206 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 98 (-5) rows, 2 (0) columns and 196 (-10) elements
# 0  Obj 0 Primal inf 77.961692 (98) Dual inf 43.036498 (2) w.o. free dual inf (0)
# 4  Obj 2808.5432
# Optimal - objective value 2808.5432
# After Postsolve, objective 2808.5432, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2808.543182 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e26e6879255844e6a5444ea312d77ffc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e26e6879255844e6a5444ea312d77ffc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 281 COLUMNS
# At line 836 RHS
# At line 1113 BOUNDS
# At line 1116 ENDATA
# Problem MODEL has 276 rows, 2 columns and 552 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 252 (-24) rows, 2 (0) columns and 504 (-48) elements
# 0  Obj 0 Primal inf 217.51032 (252) Dual inf 85.191898 (2) w.o. free dual inf (0)
# 2  Obj 7758.36
# 2  Obj 1.391475e+13 Primal inf 3.8730913e+11 (79) Dual inf 9.4647289e+14 (2) w.o. free dual inf (1)
# 3  Obj 7709.1232
# Optimal - objective value 7709.1232
# After Postsolve, objective 7709.1232, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 7709.123192 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9a866cb297b84266b546631a2e4a4b56-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9a866cb297b84266b546631a2e4a4b56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 162 COLUMNS
# At line 479 RHS
# At line 637 BOUNDS
# At line 640 ENDATA
# Problem MODEL has 157 rows, 2 columns and 314 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 151 (-6) rows, 2 (0) columns and 302 (-12) elements
# 0  Obj 0 Primal inf 132.78888 (151) Dual inf 48.549498 (2) w.o. free dual inf (0)
# 2  Obj 4413.27
# 2  Obj 8.1375e+12 Primal inf 2.3836583e+11 (45) Dual inf 5.4629979e+14 (2) w.o. free dual inf (1)
# 3  Obj 4384.4758
# Optimal - objective value 4384.4758
# After Postsolve, objective 4384.4758, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4384.475769 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e54ac575a9b84f0ba2ce44b2f4bb6041-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e54ac575a9b84f0ba2ce44b2f4bb6041-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 149 (-6) rows, 2 (0) columns and 298 (-12) elements
# 0  Obj 0 Primal inf 131.11298 (149) Dual inf 48.013798 (2) w.o. free dual inf (0)
# 2  Obj 4357.05
# 2  Obj 8.24075e+12 Primal inf 2.3052443e+11 (44) Dual inf 5.3313187e+14 (2) w.o. free dual inf (1)
# 3  Obj 4327.8904
# Optimal - objective value 4327.8904
# After Postsolve, objective 4327.8904, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4327.890423 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f4031b7740034ba6aba5c07cd97af975-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f4031b7740034ba6aba5c07cd97af975-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 186 COLUMNS
# At line 551 RHS
# At line 733 BOUNDS
# At line 736 ENDATA
# Problem MODEL has 181 rows, 2 columns and 362 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 164 (-17) rows, 2 (0) columns and 328 (-34) elements
# 0  Obj 0 Primal inf 128.14158 (164) Dual inf 75.484498 (2) w.o. free dual inf (0)
# 4  Obj 4934.7523
# Optimal - objective value 4934.7523
# After Postsolve, objective 4934.7523, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4934.752273 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/69ade7126e52454b8ef74721f326c6cb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/69ade7126e52454b8ef74721f326c6cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 111 COLUMNS
# At line 326 RHS
# At line 433 BOUNDS
# At line 436 ENDATA
# Problem MODEL has 106 rows, 2 columns and 212 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 101 (-5) rows, 2 (0) columns and 202 (-10) elements
# 0  Obj 0 Primal inf 79.793937 (101) Dual inf 44.248998 (2) w.o. free dual inf (0)
# 4  Obj 2890.1591
# Optimal - objective value 2890.1591
# After Postsolve, objective 2890.1591, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2890.159091 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/111db573c9604ce98db49e3017afd9ef-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/111db573c9604ce98db49e3017afd9ef-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 108 COLUMNS
# At line 317 RHS
# At line 421 BOUNDS
# At line 424 ENDATA
# Problem MODEL has 103 rows, 2 columns and 206 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 98 (-5) rows, 2 (0) columns and 196 (-10) elements
# 0  Obj 0 Primal inf 77.961692 (98) Dual inf 43.036498 (2) w.o. free dual inf (0)
# 4  Obj 2808.5432
# Optimal - objective value 2808.5432
# After Postsolve, objective 2808.5432, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2808.543182 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cc50e25e7deb4a57b71fe8f345afe6bb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cc50e25e7deb4a57b71fe8f345afe6bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 149 (-6) rows, 2 (0) columns and 298 (-12) elements
# 0  Obj 0 Primal inf 131.11298 (149) Dual inf 48.013798 (2) w.o. free dual inf (0)
# 2  Obj 4357.05
# 2  Obj 8.24075e+12 Primal inf 2.3052443e+11 (44) Dual inf 5.3313187e+14 (2) w.o. free dual inf (1)
# 3  Obj 4327.8904
# Optimal - objective value 4327.8904
# After Postsolve, objective 4327.8904, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4327.890423 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/28624c7951964e6c9a03f8cf6a6a263b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/28624c7951964e6c9a03f8cf6a6a263b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 574 COLUMNS
# At line 1715 RHS
# At line 2285 BOUNDS
# At line 2288 ENDATA
# Problem MODEL has 569 rows, 2 columns and 1138 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 522 (-47) rows, 2 (0) columns and 1044 (-94) elements
# 0  Obj 0 Primal inf 762.24464 (522) Dual inf 75.768212 (2) w.o. free dual inf (0)
# 4  Obj 8276.4422
# Optimal - objective value 8276.4422
# After Postsolve, objective 8276.4422, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 8276.442167 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3091221e03644a79a71c90b914228943-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3091221e03644a79a71c90b914228943-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 257 (-27) rows, 2 (0) columns and 514 (-54) elements
# 0  Obj 0 Primal inf 39.245998 (257) Dual inf 556.0961 (2) w.o. free dual inf (0)
# 4  Obj 4929.4232
# Optimal - objective value 4929.4232
# After Postsolve, objective 4929.4232, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4929.423155 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8201461cdb4b4a9aea3e68dbeee003-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8201461cdb4b4a9aea3e68dbeee003-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 266 (-18) rows, 2 (0) columns and 532 (-36) elements
# 0  Obj 0 Primal inf 40.798151 (266) Dual inf 420.1678 (2) w.o. free dual inf (0)
# 4  Obj 4480.0621
# Optimal - objective value 4480.0621
# After Postsolve, objective 4480.0621, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4480.062131 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/be915b8a9d7e4e5087e58990b1ffe48c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/be915b8a9d7e4e5087e58990b1ffe48c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 255 (-29) rows, 2 (0) columns and 510 (-58) elements
# 0  Obj 0 Primal inf 38.910867 (255) Dual inf 558.6094 (2) w.o. free dual inf (0)
# 4  Obj 4930.5089
# Optimal - objective value 4930.5089
# After Postsolve, objective 4930.5089, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4930.508904 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4daec10467f545dca700313a6b9a8e80-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4daec10467f545dca700313a6b9a8e80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 257 (-27) rows, 2 (0) columns and 514 (-54) elements
# 0  Obj 0 Primal inf 39.249685 (257) Dual inf 553.9553 (2) w.o. free dual inf (0)
# 4  Obj 4928.8229
# Optimal - objective value 4928.8229
# After Postsolve, objective 4928.8229, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4928.822854 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b995f77b5cdd4e24b6dfa599386fcf51-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b995f77b5cdd4e24b6dfa599386fcf51-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 289 COLUMNS
# At line 860 RHS
# At line 1145 BOUNDS
# At line 1148 ENDATA
# Problem MODEL has 284 rows, 2 columns and 568 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 272 (-12) rows, 2 (0) columns and 544 (-24) elements
# 0  Obj 0 Primal inf 401.50797 (272) Dual inf 38.635204 (2) w.o. free dual inf (0)
# 5  Obj 4240.3223
# Optimal - objective value 4240.3223
# After Postsolve, objective 4240.3223, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4240.322331 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7998e86e2989420eb3c67bd2241eacb8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7998e86e2989420eb3c67bd2241eacb8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# At line 745 BOUNDS
# At line 748 ENDATA
# Problem MODEL has 184 rows, 2 columns and 368 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 168 (-16) rows, 2 (0) columns and 336 (-32) elements
# 0  Obj 0 Primal inf 25.54782 (168) Dual inf 368.2455 (2) w.o. free dual inf (0)
# 4  Obj 3305.2129
# Optimal - objective value 3305.2129
# After Postsolve, objective 3305.2129, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3305.21295 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/edef41db2a3f4347a7277fd8c1f9543e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/edef41db2a3f4347a7277fd8c1f9543e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 283 COLUMNS
# At line 842 RHS
# At line 1121 BOUNDS
# At line 1124 ENDATA
# Problem MODEL has 278 rows, 2 columns and 556 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 251 (-27) rows, 2 (0) columns and 502 (-54) elements
# 0  Obj 0 Primal inf 38.304995 (251) Dual inf 548.2049 (2) w.o. free dual inf (0)
# 4  Obj 4847.7383
# Optimal - objective value 4847.7383
# After Postsolve, objective 4847.7383, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4847.738251 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/73c69d3103ea47adbafc862aca3951d9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/73c69d3103ea47adbafc862aca3951d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 287 COLUMNS
# At line 854 RHS
# At line 1137 BOUNDS
# At line 1140 ENDATA
# Problem MODEL has 282 rows, 2 columns and 564 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 255 (-27) rows, 2 (0) columns and 510 (-54) elements
# 0  Obj 0 Primal inf 38.937805 (255) Dual inf 552.6389 (2) w.o. free dual inf (0)
# 4  Obj 4901.7375
# Optimal - objective value 4901.7375
# After Postsolve, objective 4901.7375, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4901.737481 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b0dd43b7cc614588be23dd3d69e1f950-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b0dd43b7cc614588be23dd3d69e1f950-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 162 COLUMNS
# At line 479 RHS
# At line 637 BOUNDS
# At line 640 ENDATA
# Problem MODEL has 157 rows, 2 columns and 314 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 149 (-8) rows, 2 (0) columns and 298 (-16) elements
# 0  Obj 0 Primal inf 22.527501 (149) Dual inf 315.7974 (2) w.o. free dual inf (0)
# 5  Obj 2775.9492
# Optimal - objective value 2775.9492
# After Postsolve, objective 2775.9492, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2775.949181 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/47f641c7142d4a0baa503c05efae34aa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/47f641c7142d4a0baa503c05efae34aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 190 COLUMNS
# At line 563 RHS
# At line 749 BOUNDS
# At line 752 ENDATA
# Problem MODEL has 185 rows, 2 columns and 370 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 169 (-16) rows, 2 (0) columns and 338 (-32) elements
# 0  Obj 0 Primal inf 25.682422 (169) Dual inf 370.9369 (2) w.o. free dual inf (0)
# 5  Obj 3319.7649
# Optimal - objective value 3319.7649
# After Postsolve, objective 3319.7649, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3319.76492 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/408dce3d53884fe39e059c38112064be-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/408dce3d53884fe39e059c38112064be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# ...
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b51e4dd4fe01491d9c815142a15081e8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b51e4dd4fe01491d9c815142a15081e8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 167 COLUMNS
# At line 494 RHS
# At line 657 BOUNDS
# At line 660 ENDATA
# Problem MODEL has 162 rows, 2 columns and 324 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 158 (-4) rows, 2 (0) columns and 316 (-8) elements
# 0  Obj -0 Dual inf 67.413842 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 67.413842 (2) w.o. free dual inf (0)
# 2  Obj 15.586931
# Optimal - objective value 15.586931
# After Postsolve, objective 15.586931, infeasibilities - dual 0 (0), primal 1.49e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 15.586931 Primal inf 4.0869383e-07 (1)
# 1  Obj 15.584838
# Optimal - objective value 15.584838
# Optimal objective 15.58483785 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fedc1996a41b4b2db2a19fe4e3985669-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fedc1996a41b4b2db2a19fe4e3985669-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 151 (-4) rows, 2 (0) columns and 302 (-8) elements
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 2  Obj 14.917429
# Optimal - objective value 14.917429
# After Postsolve, objective 14.917429, infeasibilities - dual 0 (0), primal 1.49e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 14.917429 Primal inf 4.0869383e-07 (1)
# 1  Obj 14.91551
# Optimal - objective value 14.91551
# Optimal objective 14.91550992 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd6d9d2d454c477ca41ef42f4e1ab3f5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd6d9d2d454c477ca41ef42f4e1ab3f5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 186 COLUMNS
# At line 551 RHS
# At line 733 BOUNDS
# At line 736 ENDATA
# Problem MODEL has 181 rows, 2 columns and 362 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 177 (-4) rows, 2 (0) columns and 354 (-8) elements
# 0  Obj -0 Dual inf 77.709167 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 77.709167 (2) w.o. free dual inf (0)
# 2  Obj 13.239095
# Optimal - objective value 13.239095
# After Postsolve, objective 13.239095, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13.23909453 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2c64b00a3b7c4e8d8c01d783407ec680-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2c64b00a3b7c4e8d8c01d783407ec680-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 189 COLUMNS
# At line 560 RHS
# At line 745 BOUNDS
# At line 748 ENDATA
# Problem MODEL has 184 rows, 2 columns and 368 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 180 (-4) rows, 2 (0) columns and 360 (-8) elements
# 0  Obj -0 Dual inf 78.755034 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 78.755034 (2) w.o. free dual inf (0)
# 2  Obj 13.446479
# Optimal - objective value 13.446479
# After Postsolve, objective 13.446479, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13.44647898 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f68122a013b4428a829c20ab7f53095c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f68122a013b4428a829c20ab7f53095c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 108 COLUMNS
# At line 317 RHS
# At line 421 BOUNDS
# At line 424 ENDATA
# Problem MODEL has 103 rows, 2 columns and 206 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 103 (0) rows, 2 (0) columns and 206 (0) elements
# 0  Obj -0 Dual inf 45.108365 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 45.108365 (2) w.o. free dual inf (0)
# 3  Obj 9.9191444
# Optimal - objective value 9.9191444
# Optimal objective 9.919144412 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/17c8636e6d9d48bb885c3ee92480673d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/17c8636e6d9d48bb885c3ee92480673d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 281 COLUMNS
# At line 836 RHS
# At line 1113 BOUNDS
# At line 1116 ENDATA
# Problem MODEL has 276 rows, 2 columns and 552 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 262 (-14) rows, 2 (0) columns and 524 (-28) elements
# 0  Obj -0 Dual inf 115.35446 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 115.35446 (2) w.o. free dual inf (0)
# 2  Obj 19.214986
# Optimal - objective value 19.214986
# After Postsolve, objective 19.214986, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 19.21498639 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/21f5a0dfc3f3465887b4551377eea643-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/21f5a0dfc3f3465887b4551377eea643-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 162 COLUMNS
# At line 479 RHS
# At line 637 BOUNDS
# At line 640 ENDATA
# Problem MODEL has 157 rows, 2 columns and 314 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 153 (-4) rows, 2 (0) columns and 306 (-8) elements
# 0  Obj -0 Dual inf 66.646155 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 66.646155 (2) w.o. free dual inf (0)
# 2  Obj 15.108755
# Optimal - objective value 15.108755
# After Postsolve, objective 15.108755, infeasibilities - dual 0 (0), primal 1.49e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 15.108755 Primal inf 4.0869383e-07 (1)
# 1  Obj 15.106787
# Optimal - objective value 15.106787
# Optimal objective 15.10678711 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31d00aadf2fd4d53a4d61a4d7bd4d150-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31d00aadf2fd4d53a4d61a4d7bd4d150-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 151 (-4) rows, 2 (0) columns and 302 (-8) elements
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 2  Obj 14.917429
# Optimal - objective value 14.917429
# After Postsolve, objective 14.917429, infeasibilities - dual 0 (0), primal 1.49e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 14.917429 Primal inf 4.0869383e-07 (1)
# 1  Obj 14.91551
# Optimal - objective value 14.91551
# Optimal objective 14.91550992 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dda500c55fdd4c4b979017b0b14e31f1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dda500c55fdd4c4b979017b0b14e31f1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 186 COLUMNS
# At line 551 RHS
# At line 733 BOUNDS
# At line 736 ENDATA
# Problem MODEL has 181 rows, 2 columns and 362 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 177 (-4) rows, 2 (0) columns and 354 (-8) elements
# 0  Obj -0 Dual inf 77.709167 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 77.709167 (2) w.o. free dual inf (0)
# 2  Obj 13.239095
# Optimal - objective value 13.239095
# After Postsolve, objective 13.239095, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 13.23909453 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d579a3b14d8f4ca999a5f5ba092cc9ee-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d579a3b14d8f4ca999a5f5ba092cc9ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 111 COLUMNS
# At line 326 RHS
# At line 433 BOUNDS
# At line 436 ENDATA
# Problem MODEL has 106 rows, 2 columns and 212 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 106 (0) rows, 2 (0) columns and 212 (0) elements
# 0  Obj -0 Dual inf 45.291925 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 45.291925 (2) w.o. free dual inf (0)
# 3  Obj 10.205986
# Optimal - objective value 10.205986
# Optimal objective 10.20598584 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c643bff7e327483ca94ea531655aadb0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c643bff7e327483ca94ea531655aadb0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 108 COLUMNS
# At line 317 RHS
# At line 421 BOUNDS
# At line 424 ENDATA
# Problem MODEL has 103 rows, 2 columns and 206 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 103 (0) rows, 2 (0) columns and 206 (0) elements
# 0  Obj -0 Dual inf 45.108365 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 45.108365 (2) w.o. free dual inf (0)
# 3  Obj 9.9191444
# Optimal - objective value 9.9191444
# Optimal objective 9.919144412 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fb7cac687a1e409da20850ff675e87a1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fb7cac687a1e409da20850ff675e87a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 160 COLUMNS
# At line 473 RHS
# At line 629 BOUNDS
# At line 632 ENDATA
# Problem MODEL has 155 rows, 2 columns and 310 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 151 (-4) rows, 2 (0) columns and 302 (-8) elements
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 66.249881 (2) w.o. free dual inf (0)
# 2  Obj 14.917429
# Optimal - objective value 14.917429
# After Postsolve, objective 14.917429, infeasibilities - dual 0 (0), primal 1.49e-05 (1)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 14.917429 Primal inf 4.0869383e-07 (1)
# 1  Obj 14.91551
# Optimal - objective value 14.91551
# Optimal objective 14.91550992 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any tumor C, if C is high_mean_texture, then mean perimeter(C) >= 168*mean smoothness(C) + 304/9, with equality on 2 instances.
#
# Conjecture 2.  For any tumor C, if C is high_mean_radius and C is high_mean_perimeter, then mean perimeter(C) >= 80/3*mean smoothness(C) + 671/8, with equality on 2 instances.
#
# Conjecture 3.  For any tumor C, if C is high_mean_radius and C is high_mean_texture and C is high_mean_perimeter, then mean perimeter(C) >= 887/7*mean smoothness(C) + 597/8, with equality on 2 instances.
#
# Conjecture 4.  For any tumor C, mean area(C) <= 169721/5*mean smoothness(C) + -10607/9, with equality on 2 instances.
#
# Conjecture 5.  For any tumor C, if C is high_mean_smoothness, then mean area(C) <= 966263/10*mean smoothness(C) + -55813/7, with equality on 2 instances.
#
# Conjecture 6.  For any tumor C, if C is high_mean_texture, then mean area(C) >= 95*mean radius(C) + -741, with equality on 2 instances.
#
# Conjecture 7.  For any tumor C, if C is high_mean_radius, then mean area(C) >= -220*mean smoothness(C) + 3989/7, with equality on 2 instances.
#
# Conjecture 8.  For any tumor C, if C is high_mean_perimeter, then mean area(C) >= -8257/9*mean smoothness(C) + 6189/10, with equality on 2 instances.
#
# Conjecture 9.  For any tumor C, if C is high_mean_smoothness, then mean area(C) >= -37423/9*mean smoothness(C) + 630, with equality on 2 instances.
#
# Conjecture 10.  For any tumor C, if C is high_mean_radius and C is high_mean_texture, then mean area(C) >= -248/9*mean smoothness(C) + 2239/4, with equality on 2 instances.
#
# Conjecture 11.  For any tumor C, if C is high_mean_radius and C is high_mean_smoothness, then mean area(C) >= 4691/8*mean smoothness(C) + 967/2, with equality on 2 instances.
#
# Conjecture 12.  For any tumor C, if C is high_mean_perimeter and C is high_mean_area, then mean area(C) >= -1723/8*mean smoothness(C) + 5194/9, with equality on 2 instances.
#
# Conjecture 13.  For any tumor C, if C is high_mean_perimeter and C is high_mean_smoothness, then mean area(C) >= -7421/6*mean smoothness(C) + 1960/3, with equality on 2 instances.
#
# Conjecture 14.  For any tumor C, if C is high_mean_texture and C is high_mean_perimeter and C is high_mean_smoothness, then mean area(C) >= -1417/4*mean smoothness(C) + 5649/10, with equality on 2 instances.
#
# Conjecture 15.  For any tumor C, if C is high_mean_radius, then mean radius(C) >= 1/7*mean perimeter(C) + 4/5, with equality on 1 instances.
#
# Conjecture 16.  For any tumor C, mean radius(C) <= -1/10*mean texture(C) + 119/4, with equality on 0 instances.
#
# Conjecture 17.  For any tumor C, mean radius(C) <= 1/7*mean perimeter(C) + 4/9, with equality on 0 instances.
#
# Conjecture 18.  For any tumor C, if C is high_mean_texture, then mean radius(C) <= 1/7*mean perimeter(C) + 3/7, with equality on 0 instances.
#
# Conjecture 19.  For any tumor C, if C is high_mean_smoothness, then mean radius(C) <= 1/7*mean perimeter(C) + 3/4, with equality on 0 instances.
#
# Conjecture 20.  For any tumor C, if C is high_mean_radius and C is high_mean_texture, then mean radius(C) <= 1/7*mean perimeter(C) + 19/10, with equality on 0 instances.
