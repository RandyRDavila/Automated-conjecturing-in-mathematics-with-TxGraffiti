# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="positive integer"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="n"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="n"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Generate synthetic data for integers
n_samples = 1_000
np.random.seed(42)

integers = np.arange(1, n_samples + 1)

# Define properties related to Goldbach's Conjecture, Fermat's Last Theorem, and the Collatz Conjecture
def is_goldbach_composite(n):
    if n <= 2 or n % 2 != 0:
        return False
    for p in range(2, n // 2 + 1):
        if is_prime_number(p) and is_prime_number(n - p):
            return True
    return False

def is_fermat_witness(n, k=3):
    return any([a**k + b**k == n**k for a in range(1, n) for b in range(1, n)])

def collatz_steps(n):
    steps = 0
    while n != 1:
        if n % 2 == 0:
            n = n // 2
        else:
            n = 3 * n + 1
        steps += 1
    return steps

# Define helper functions
def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors

def is_prime_number(n):
    if n <= 1:
        return False
    for i in range(2, int(np.sqrt(n)) + 1):
        if n % i == 0:
            return False
    return True

# Generate properties
sum_of_digits = np.array([sum(int(digit) for digit in str(i)) for i in integers])
num_divisors = np.array([len([d for d in range(1, i + 1) if i % d == 0]) for i in integers])
is_prime = np.array([is_prime_number(i) for i in integers])
is_even = integers % 2 == 0
is_goldbach = np.array([is_goldbach_composite(i) for i in integers])
is_fermat = np.array([is_fermat_witness(i) for i in integers])
collatz = np.array([collatz_steps(i) for i in integers])

# Create the DataFrame
data = {
    'value': integers,
    'sum_of_digits': sum_of_digits,
    'num_divisors': num_divisors,
    'prime': is_prime,
    'even': is_even,
    'goldbach': is_goldbach,
    'fermat': is_fermat,
    'collatz_steps': collatz,
    'sqrt(collatz_steps)': np.sqrt(collatz),
    'value^2': integers**2,
    'sum_of_digits^2': sum_of_digits**2,
    'sum_of_digits/num_divisors': sum_of_digits / num_divisors
}
df = pd.DataFrame(data)

# Define the targets, invariants, and properties
targets = ["sum_of_digits", "num_divisors", "collatz_steps", "sqrt(collatz_steps)"]
invariants = ["value", "sum_of_digits", "num_divisors", "value^2", "sqrt(collatz_steps)", "sum_of_digits^2", "sum_of_digits/num_divisors"]
properties = ["prime", "even", "goldbach", "fermat"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/838820e1c2b24cb293e05cdb6e1cc012-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/838820e1c2b24cb293e05cdb6e1cc012-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 704.31033 (1000) Dual inf 946.26298 (2) w.o. free dual inf (0)
# 4  Obj 22015
# Optimal - objective value 22015
# Optimal objective 22015 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/aff02bb38c9d443a973056f8aa9b9565-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/aff02bb38c9d443a973056f8aa9b9565-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 168 (0) rows, 2 (0) columns and 336 (0) elements
# 0  Obj 0 Primal inf 131.74727 (168) Dual inf 125.14836 (2) w.o. free dual inf (0)
# 5  Obj 3618.95
# Optimal - objective value 3618.95
# Optimal objective 3618.95 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0f7060e24bda4e2b899004c5dc8c04a8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0f7060e24bda4e2b899004c5dc8c04a8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 500 (0) rows, 2 (0) columns and 1000 (0) elements
# 0  Obj 0 Primal inf 337.50536 (500) Dual inf 408.02188 (2) w.o. free dual inf (0)
# 3  Obj 10515
# Optimal - objective value 10515
# Optimal objective 10515 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/68e26a6a4f74461182ee1d2b5aeaf609-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/68e26a6a4f74461182ee1d2b5aeaf609-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 499 (0) rows, 2 (0) columns and 998 (0) elements
# 0  Obj 0 Primal inf 336.09115 (499) Dual inf 354.66857 (2) w.o. free dual inf (0)
# 3  Obj 10498.96
# Optimal - objective value 10498.96
# Optimal objective 10498.96 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2927b218438246388fc07e837ef262a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2927b218438246388fc07e837ef262a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd62081c19aa4060b101f1ec46f0419d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd62081c19aa4060b101f1ec46f0419d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# 0  Obj 0 Primal inf 1.9999999 (1) Dual inf 0.0299998 (2) w.o. free dual inf (0)
# 1  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4c5993fee915405b97e3e780ebf73dfe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4c5993fee915405b97e3e780ebf73dfe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2079fa755ff749ff8c166e0c9653369c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2079fa755ff749ff8c166e0c9653369c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a9286acc7499412188b61b993ee4de8d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a9286acc7499412188b61b993ee4de8d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 499 (0) rows, 2 (0) columns and 998 (0) elements
# 0  Obj 0 Primal inf 336.09115 (499) Dual inf 354.66857 (2) w.o. free dual inf (0)
# 3  Obj 10498.96
# Optimal - objective value 10498.96
# Optimal objective 10498.96 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5fc5def61c9646f4949b122052454096-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5fc5def61c9646f4949b122052454096-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31325611737c45b0913f92d5e3f0e77a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31325611737c45b0913f92d5e3f0e77a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/68711545be504ee8ad3b3decab3f7da7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/68711545be504ee8ad3b3decab3f7da7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4b1d75ea765a4989bb9d31f3dee9d391-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4b1d75ea765a4989bb9d31f3dee9d391-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/100ad9f2bcf14f7192d7bc947bba3642-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/100ad9f2bcf14f7192d7bc947bba3642-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0aebef139f394843b4e03f8fa7cccae2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0aebef139f394843b4e03f8fa7cccae2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ac2b15f83ee249d2b1b0a9aa35068d20-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ac2b15f83ee249d2b1b0a9aa35068d20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-978) rows, 2 (0) columns and 44 (-1956) elements
# 0  Obj 0 Primal inf 134.79737 (22) Dual inf 22.496343 (2) w.o. free dual inf (0)
# 3  Obj 26767.25
# Optimal - objective value 26767.25
# After Postsolve, objective 26767.25, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 26767.25 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/37f8267088e34a7f89c26a387bc22343-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/37f8267088e34a7f89c26a387bc22343-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (-167) rows, 2 (0) columns and 2 (-334) elements
# 0  Obj 0 Primal inf 24.999999 (1) Dual inf 5.039998 (2) w.o. free dual inf (0)
# 1  Obj 4200
# Optimal - objective value 4200
# After Postsolve, objective 4200, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4200 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5947355d151c4b57abfb8a15861ad94c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5947355d151c4b57abfb8a15861ad94c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 21 (-479) rows, 2 (0) columns and 42 (-958) elements
# 0  Obj 0 Primal inf 102.10601 (21) Dual inf 15.837422 (2) w.o. free dual inf (0)
# 4  Obj 12630.125
# Optimal - objective value 12630.125
# After Postsolve, objective 12630.125, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12630.125 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ff6d9cd8b02e4f87ab3651ad8d58e71a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ff6d9cd8b02e4f87ab3651ad8d58e71a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 20 (-479) rows, 2 (0) columns and 40 (-958) elements
# 0  Obj 0 Primal inf 100.69179 (20) Dual inf 17.405752 (2) w.o. free dual inf (0)
# 4  Obj 12603.875
# Optimal - objective value 12603.875
# After Postsolve, objective 12603.875, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12603.875 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/06c5840fac7e46ad9d8d36a1a074c75f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/06c5840fac7e46ad9d8d36a1a074c75f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8f28d023034948149436a9e95fdb6d6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8f28d023034948149436a9e95fdb6d6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# 0  Obj 0 Primal inf 1.9999999 (1) Dual inf 0.0299998 (2) w.o. free dual inf (0)
# 1  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/438ed17b554d4ac494a5d75ad172a30a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/438ed17b554d4ac494a5d75ad172a30a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4873680e14b94a58956158a3810ab29d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4873680e14b94a58956158a3810ab29d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d8204ed923414cf5ae9c703d21fc6ed8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d8204ed923414cf5ae9c703d21fc6ed8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 20 (-479) rows, 2 (0) columns and 40 (-958) elements
# 0  Obj 0 Primal inf 100.69179 (20) Dual inf 17.405752 (2) w.o. free dual inf (0)
# 4  Obj 12603.875
# Optimal - objective value 12603.875
# After Postsolve, objective 12603.875, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12603.875 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2386a1c7c87e49f1827f035cd5a7116c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2386a1c7c87e49f1827f035cd5a7116c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1a752eca7da6440d8c1842a032e094f8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1a752eca7da6440d8c1842a032e094f8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bb26861df6a84695a4d6c7615f121aa3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bb26861df6a84695a4d6c7615f121aa3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ccc309fc6f724d8a88e64d264d1ded89-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ccc309fc6f724d8a88e64d264d1ded89-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c8227022093f4c36be11f1044258b8d3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c8227022093f4c36be11f1044258b8d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/83cbc1dfcff34f6180318c0ed96d4515-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/83cbc1dfcff34f6180318c0ed96d4515-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a273fe0ce9844e18b0df450923ee3288-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a273fe0ce9844e18b0df450923ee3288-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 54.725756 (1000) Dual inf 105883.65 (2) w.o. free dual inf (0)
# 8  Obj 22772.609
# Optimal - objective value 22772.609
# Optimal objective 22772.60929 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d6eee3e5d8c448a095d1ee691011cf75-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d6eee3e5d8c448a095d1ee691011cf75-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 168 (0) rows, 2 (0) columns and 336 (0) elements
# 0  Obj 0 Primal inf 13.507496 (168) Dual inf 11125.57 (2) w.o. free dual inf (0)
# 8  Obj 3764.4263
# Optimal - objective value 3764.4263
# Optimal objective 3764.42633 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5b68333dc3544a429cc8918b20f438e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5b68333dc3544a429cc8918b20f438e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 500 (0) rows, 2 (0) columns and 1000 (0) elements
# 0  Obj 0 Primal inf 25.859432 (500) Dual inf 37603.284 (2) w.o. free dual inf (0)
# 8  Obj 10893.841
# Optimal - objective value 10893.841
# Optimal objective 10893.84124 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cdb35fac357c48ee8074500b66e17fec-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cdb35fac357c48ee8074500b66e17fec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 499 (0) rows, 2 (0) columns and 998 (0) elements
# 0  Obj 0 Primal inf 24.859432 (499) Dual inf 26747.018 (2) w.o. free dual inf (0)
# 8  Obj 10875.104
# Optimal - objective value 10875.104
# Optimal objective 10875.10401 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab13493353ab41a98a33f36f102f2251-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab13493353ab41a98a33f36f102f2251-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ce5d5e2348344f8f98afa169a17b08a2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ce5d5e2348344f8f98afa169a17b08a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# 0  Obj 0 Primal inf 0.4999999 (1) Dual inf 0.0799998 (2) w.o. free dual inf (0)
# 1  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/02d489bfd2594c18b46959b2dd59a215-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/02d489bfd2594c18b46959b2dd59a215-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cbd7cc3cdbc14f03a833465a3db545db-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cbd7cc3cdbc14f03a833465a3db545db-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/490a4b38d2934e729597a84d1158ecd0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/490a4b38d2934e729597a84d1158ecd0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 499 (0) rows, 2 (0) columns and 998 (0) elements
# 0  Obj 0 Primal inf 24.859432 (499) Dual inf 26747.018 (2) w.o. free dual inf (0)
# 8  Obj 10875.104
# Optimal - objective value 10875.104
# Optimal objective 10875.10401 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d285f41954dc4ade90a6501c4c33eb94-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d285f41954dc4ade90a6501c4c33eb94-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3c30d6843b32413a8a935ee6656242ca-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3c30d6843b32413a8a935ee6656242ca-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f4eacf2436e549b49789609fad67d8a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f4eacf2436e549b49789609fad67d8a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c749d546b2f44005afb8745e1dcf9f1e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c749d546b2f44005afb8745e1dcf9f1e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/15a2b92248aa42f997654296b0ff6976-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/15a2b92248aa42f997654296b0ff6976-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1bd1acaadb15447eba353b60166649eb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1bd1acaadb15447eba353b60166649eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# ...
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 116 (-884) rows, 2 (0) columns and 232 (-1768) elements
# 0  Obj -0 Dual inf 158.9534 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 158.9534 (2) w.o. free dual inf (0)
# 2  Obj 1038.5011
# Optimal - objective value 1038.5011
# After Postsolve, objective 1038.5011, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1038.501059 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cead7ac3051846c2b0106592bed4a45d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cead7ac3051846c2b0106592bed4a45d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 17 (-151) rows, 2 (0) columns and 34 (-302) elements
# 0  Obj -0 Dual inf 4.8690496 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 4.8690496 (2) w.o. free dual inf (0)
# 2  Obj 559.94288
# Optimal - objective value 559.94288
# After Postsolve, objective 559.94288, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 559.9428763 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/018224b8a2ba4d8ea05ed8798c6dc732-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/018224b8a2ba4d8ea05ed8798c6dc732-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (-403) rows, 2 (0) columns and 194 (-806) elements
# 0  Obj -0 Dual inf 54.416212 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 54.416212 (2) w.o. free dual inf (0)
# 2  Obj 763.83503
# Optimal - objective value 763.83503
# After Postsolve, objective 763.83503, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 763.8350327 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00bcb858254741e499a3be003899757b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00bcb858254741e499a3be003899757b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (-402) rows, 2 (0) columns and 194 (-804) elements
# 0  Obj -0 Dual inf 54.336212 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 54.336212 (2) w.o. free dual inf (0)
# 2  Obj 798.21754
# Optimal - objective value 798.21754
# After Postsolve, objective 798.21754, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 798.2175438 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2dcce24730af459b9e5447ba7d387f87-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2dcce24730af459b9e5447ba7d387f87-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0c7df132379b4f968ee3521a0f546733-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0c7df132379b4f968ee3521a0f546733-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/262b0d2abb1a49cd8a7eef865865ff5a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/262b0d2abb1a49cd8a7eef865865ff5a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3563cdb7cb58497aac9166c4f090eba8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3563cdb7cb58497aac9166c4f090eba8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e275217b6c324d34b2d2810d53f20819-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e275217b6c324d34b2d2810d53f20819-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 504 COLUMNS
# At line 1505 RHS
# At line 2005 BOUNDS
# At line 2008 ENDATA
# Problem MODEL has 499 rows, 2 columns and 998 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (-402) rows, 2 (0) columns and 194 (-804) elements
# 0  Obj -0 Dual inf 54.336212 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 54.336212 (2) w.o. free dual inf (0)
# 2  Obj 798.21754
# Optimal - objective value 798.21754
# After Postsolve, objective 798.21754, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 798.2175438 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0632562e3fee4d0fb65c23ae843f9f42-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0632562e3fee4d0fb65c23ae843f9f42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d01dca54df0841039f82bd98d6058a3d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d01dca54df0841039f82bd98d6058a3d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8c73a60f4d46749e0587902de65be1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8c73a60f4d46749e0587902de65be1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/62978989ce7c4646a4cd9091beff782a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/62978989ce7c4646a4cd9091beff782a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0aee25e591d642898f3f04ca9126a5d8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0aee25e591d642898f3f04ca9126a5d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/18455f625f5f460488b08e996f74cdce-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/18455f625f5f460488b08e996f74cdce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any positive integer n, if n is prime, then sum_of_digits(n) <= 2*sum_of_digits/num_divisors(n) + 0, with equality on 168 instances.
#
# Conjecture 2.  For any positive integer n, collatz_steps(n) >= 29/2*sqrt(collatz_steps)(n) + -105/2, with equality on 15 instances.
#
# Conjecture 3.  For any positive integer n, num_divisors(n) <= -4/3*sum_of_digits(n) + 48, with equality on 9 instances.
#
# Conjecture 4.  For any positive integer n, sum_of_digits(n) >= 21/10*sum_of_digits/num_divisors(n) + -11/10, with equality on 7 instances.
#
# Conjecture 5.  For any positive integer n, num_divisors(n) >= 1/10*sum_of_digits/num_divisors(n) + 9/10, with equality on 7 instances.
#
# Conjecture 6.  For any positive integer n, sum_of_digits(n) <= 1/4*num_divisors(n) + 25, with equality on 4 instances.
#
# Conjecture 7.  For any positive integer n, if n is even, then sum_of_digits(n) <= 12/7*sum_of_digits/num_divisors(n) + 150/7, with equality on 3 instances.
#
# Conjecture 8.  For any positive integer n, if n is even, then sum_of_digits(n) <= -1/8*num_divisors(n) + 53/2, with equality on 2 instances.
#
# Conjecture 9.  For any positive integer n, if n is prime, then sum_of_digits(n) <= -1/2*sqrt(collatz_steps)(n) + 57/2, with equality on 2 instances.
#
# Conjecture 10.  For any positive integer n, if n is even, then num_divisors(n) <= -32/7*sum_of_digits/num_divisors(n) + 236/7, with equality on 2 instances.
#
# Conjecture 11.  For any positive integer n, num_divisors(n) >= 1/10*sqrt(collatz_steps)(n) + 1, with equality on 2 instances.
#
# Conjecture 12.  For any positive integer n, collatz_steps(n) <= 4/3*sum_of_digits(n) + 470/3, with equality on 2 instances.
#
# Conjecture 13.  For any positive integer n, if n is even, then collatz_steps(n) <= 13*sqrt(collatz_steps)(n) + -12, with equality on 2 instances.
#
# Conjecture 14.  For any positive integer n, collatz_steps(n) <= 16/3*sum_of_digits/num_divisors(n) + 470/3, with equality on 2 instances.
#
# Conjecture 15.  For any positive integer n, if n is even, then collatz_steps(n) <= 12*sum_of_digits/num_divisors(n) + 243/2, with equality on 2 instances.
#
# Conjecture 16.  For any positive integer n, if n is prime, then collatz_steps(n) >= 1*sum_of_digits(n) + -1, with equality on 2 instances.
#
# Conjecture 17.  For any positive integer n, if n is even, then collatz_steps(n) >= 1/2*num_divisors(n) + 0, with equality on 2 instances.
#
# Conjecture 18.  For any positive integer n, collatz_steps(n) >= 15/7*sum_of_digits/num_divisors(n) + -15/7, with equality on 2 instances.
#
# Conjecture 19.  For any positive integer n, if n is prime, then collatz_steps(n) >= 2*sum_of_digits/num_divisors(n) + -1, with equality on 2 instances.
#
# Conjecture 20.  For any positive integer n, if n is goldbach, then collatz_steps(n) >= 3/2*sum_of_digits/num_divisors(n) + 0, with equality on 2 instances.
