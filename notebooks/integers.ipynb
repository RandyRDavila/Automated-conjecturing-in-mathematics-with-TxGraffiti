# %% [markdown]
# # Integer Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/integers.ipynb)
#
# ## Introduction
#
# This notebook demonstrates the application of the TxGraffiti algorithm to generate conjectures on integer data. Integer sequences and properties form the basis for many famous mathematical conjectures, such as Goldbach's conjecture and the 3n+1 problem. Here, we explore how TxGraffiti can be used to discover new relationships and patterns in integer properties.
#
# ## Dataset
#
# The dataset consists of positive integers and includes various numerical and boolean properties such as:
# - **Numerical Properties**: Sum of digits, number of divisors, square root, and factorial.
# - **Boolean Properties**: Primality, even/odd status, and Goldbach property.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of integers.
# - Identify significant and non-trivial relationships between integer properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to generate the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Explore the power of TxGraffiti in uncovering hidden patterns in integer data.
#
# ---

# %%
# If running in Google Colab, you will need to pip install pulp.
# !pip install pulp

# Import the necessary libraries.
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="positive integer"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="n"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="n"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Generate synthetic data for integers
n_samples = 1_000
np.random.seed(42)

integers = np.arange(1, n_samples + 1)

# Define properties related to Goldbach's Conjecture, Fermat's Last Theorem, and the Collatz Conjecture
def is_goldbach_composite(n):
    if n <= 2 or n % 2 != 0:
        return False
    for p in range(2, n // 2 + 1):
        if is_prime_number(p) and is_prime_number(n - p):
            return True
    return False

def is_fermat_witness(n, k=3):
    return any([a**k + b**k == n**k for a in range(1, n) for b in range(1, n)])

def collatz_steps(n):
    steps = 0
    while n != 1:
        if n % 2 == 0:
            n = n // 2
        else:
            n = 3 * n + 1
        steps += 1
    return steps

# Define helper functions
def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors

def is_prime_number(n):
    if n <= 1:
        return False
    for i in range(2, int(np.sqrt(n)) + 1):
        if n % i == 0:
            return False
    return True

# Generate properties
sum_of_digits = np.array([sum(int(digit) for digit in str(i)) for i in integers])
num_divisors = np.array([len([d for d in range(1, i + 1) if i % d == 0]) for i in integers])
is_prime = np.array([is_prime_number(i) for i in integers])
is_even = integers % 2 == 0
is_goldbach = np.array([is_goldbach_composite(i) for i in integers])
is_fermat = np.array([is_fermat_witness(i) for i in integers])
collatz = np.array([collatz_steps(i) for i in integers])

# Create the DataFrame
data = {
    'value': integers,
    'sum_of_digits': sum_of_digits,
    'num_divisors': num_divisors,
    'prime': is_prime,
    'even': is_even,
    'fermat': is_fermat,
    'collatz_steps': collatz,
    'sqrt(collatz_steps)': np.sqrt(collatz),
    'value^2': integers**2,
    'sum_of_digits^2': sum_of_digits**2,
    'sum_of_digits/num_divisors': sum_of_digits / num_divisors
}
df = pd.DataFrame(data)

# Define the targets, invariants, and properties
targets = ["sum_of_digits", "num_divisors", "collatz_steps", "sqrt(collatz_steps)"]
invariants = ["value", "sum_of_digits", "num_divisors", "value^2", "sqrt(collatz_steps)", "sum_of_digits^2", "sum_of_digits/num_divisors"]
properties = ["prime", "even", "fermat"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab628aa099264f799acb0eb05be3a903-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/
-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 27 (-973) rows, 2 (0) columns and 54 (-1946) elements
# 0  Obj 0 Primal inf 26.999973 (27) Dual inf 450.33513 (2) w.o. free dual inf (0)
# 8  Obj 14379.345
# Optimal - objective value 14379.345
# After Postsolve, objective 14379.345, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 14379.34483 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1b77d825111a4aafb20ff07704612037-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1b77d825111a4aafb20ff07704612037-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 17 (-151) rows, 2 (0) columns and 34 (-302) elements
# 0  Obj 0 Primal inf 16.999983 (17) Dual inf 61.007757 (2) w.o. free dual inf (0)
# 7  Obj 2412.3667
# Optimal - objective value 2412.3667
# After Postsolve, objective 2412.3667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2412.366667 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f475b8abc1a14edcb0282179e208ee61-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f475b8abc1a14edcb0282179e208ee61-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 26 (-474) rows, 2 (0) columns and 52 (-948) elements
# 0  Obj 0 Primal inf 25.999974 (26) Dual inf 215.23942 (2) w.o. free dual inf (0)
# 8  Obj 6953.7407
# Optimal - objective value 6953.7407
# After Postsolve, objective 6953.7407, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6953.740741 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0b40ac8598924b6984184e6fcd3cca13-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0b40ac8598924b6984184e6fcd3cca13-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9bc94d1bc2cb47b9984c0f7fe9e0646a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9bc94d1bc2cb47b9984c0f7fe9e0646a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# 0  Obj 0 Primal inf 0.4999999 (1) Dual inf 0.0799998 (2) w.o. free dual inf (0)
# 1  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/080a594a0d5242008c2759c935c49e07-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/080a594a0d5242008c2759c935c49e07-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/41f617318b63487ca9dd2408de40272d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/41f617318b63487ca9dd2408de40272d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/da1e9185e45a42f0af5ca02583475522-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/da1e9185e45a42f0af5ca02583475522-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d07498c61f154ec087fc94db011cda17-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d07498c61f154ec087fc94db011cda17-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 116 (-884) rows, 2 (0) columns and 232 (-1768) elements
# 0  Obj 0 Primal inf 999.99988 (116) Dual inf 158.9534 (2) w.o. free dual inf (0)
# 4  Obj 26378.841
# Optimal - objective value 26378.841
# After Postsolve, objective 26378.841, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 26378.84147 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6718f2d93e3b46b7ae9ed254071b4f86-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6718f2d93e3b46b7ae9ed254071b4f86-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 17 (-151) rows, 2 (0) columns and 34 (-302) elements
# 0  Obj 0 Primal inf 82.198332 (17) Dual inf 4.8690496 (2) w.o. free dual inf (0)
# 1  Obj 2255
# 1  Obj 1.945e+12 Dual inf 0.777999 (1) w.o. free dual inf (0)
# 4  Obj 2255
# Optimal - objective value 2255
# After Postsolve, objective 2255, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2255 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c67d4194e420489e946d857ada37c6b4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c67d4194e420489e946d857ada37c6b4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (-403) rows, 2 (0) columns and 194 (-806) elements
# 0  Obj 0 Primal inf 922.9999 (97) Dual inf 54.416212 (2) w.o. free dual inf (0)
# 3  Obj 12189.266
# Optimal - objective value 12189.266
# After Postsolve, objective 12189.266, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12189.26633 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/65f3146a8c854a8db761c8c97ee413c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/65f3146a8c854a8db761c8c97ee413c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/622dce9fe2d24ec9976f243b1c7a7e9a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/622dce9fe2d24ec9976f243b1c7a7e9a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (0) rows, 2 (0) columns and 2 (0) elements
# 0  Obj 0 Primal inf 1.9999999 (1) Dual inf 0.0199998 (2) w.o. free dual inf (0)
# 1  Obj 2
# Optimal - objective value 2
# Optimal objective 2 - 1 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3f573f11d24f45d2a0e9f3015e82b063-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3f573f11d24f45d2a0e9f3015e82b063-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/791d2025f755420590a4eb31ef428ff1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/791d2025f755420590a4eb31ef428ff1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8c6d46e559ca425394be34c731a14191-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8c6d46e559ca425394be34c731a14191-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# ...
# 0  Obj -0 Dual inf 450.33513 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 450.33513 (2) w.o. free dual inf (0)
# 2  Obj 1813.2692
# Optimal - objective value 1813.2692
# After Postsolve, objective 1813.2692, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1813.269187 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cea9a1ca355a4c09bef2889b7e442d28-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cea9a1ca355a4c09bef2889b7e442d28-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 17 (-151) rows, 2 (0) columns and 34 (-302) elements
# 0  Obj -0 Dual inf 61.007757 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 61.007757 (2) w.o. free dual inf (0)
# 2  Obj 497.14976
# Optimal - objective value 497.14976
# After Postsolve, objective 497.14976, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 497.1497585 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b38a97140d5542d4aa150746ca0bf7fd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b38a97140d5542d4aa150746ca0bf7fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 26 (-474) rows, 2 (0) columns and 52 (-948) elements
# 0  Obj -0 Dual inf 215.23942 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 215.23942 (2) w.o. free dual inf (0)
# 2  Obj 1122.9246
# Optimal - objective value 1122.9246
# After Postsolve, objective 1122.9246, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1122.924588 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a18bee05304345a8bdf1e5ba8ee73035-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a18bee05304345a8bdf1e5ba8ee73035-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/93764a82acfd40bdb112dde373d1b166-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/93764a82acfd40bdb112dde373d1b166-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ebd262d9d5cb47109c34653175171305-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ebd262d9d5cb47109c34653175171305-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3271a1f82c8f4b9e9c0ba0ab2b1067c7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3271a1f82c8f4b9e9c0ba0ab2b1067c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d8dd2859fedc411896b71f028af4d76a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d8dd2859fedc411896b71f028af4d76a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/51530c7426d346d297a05114bc79e99e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/51530c7426d346d297a05114bc79e99e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 116 (-884) rows, 2 (0) columns and 232 (-1768) elements
# 0  Obj -0 Dual inf 158.9534 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 158.9534 (2) w.o. free dual inf (0)
# 2  Obj 1038.5011
# Optimal - objective value 1038.5011
# After Postsolve, objective 1038.5011, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1038.501059 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a40b2fce1be74158bcc69d6e575b3ac0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a40b2fce1be74158bcc69d6e575b3ac0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 173 COLUMNS
# At line 512 RHS
# At line 681 BOUNDS
# At line 684 ENDATA
# Problem MODEL has 168 rows, 2 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 17 (-151) rows, 2 (0) columns and 34 (-302) elements
# 0  Obj -0 Dual inf 4.8690496 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 4.8690496 (2) w.o. free dual inf (0)
# 2  Obj 559.94288
# Optimal - objective value 559.94288
# After Postsolve, objective 559.94288, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 559.9428763 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/263ef6ed5dc74c1a8d471d5541f47dbd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/263ef6ed5dc74c1a8d471d5541f47dbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 505 COLUMNS
# At line 1508 RHS
# At line 2009 BOUNDS
# At line 2012 ENDATA
# Problem MODEL has 500 rows, 2 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 97 (-403) rows, 2 (0) columns and 194 (-806) elements
# 0  Obj -0 Dual inf 54.416212 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 54.416212 (2) w.o. free dual inf (0)
# 2  Obj 763.83503
# Optimal - objective value 763.83503
# After Postsolve, objective 763.83503, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 763.8350327 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/86376cc032484146b73997af8345f956-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/86376cc032484146b73997af8345f956-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ee7e3d056372436a974424f59da62bcb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ee7e3d056372436a974424f59da62bcb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 11 RHS
# At line 13 BOUNDS
# At line 16 ENDATA
# Problem MODEL has 1 rows, 2 columns and 2 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-1) rows, 0 (-2) columns and 0 (-2) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0b3b0de6fee84bfd9b17b12d2c1b1204-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0b3b0de6fee84bfd9b17b12d2c1b1204-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/988df74136cb4d77b7afe0cb67326b35-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/988df74136cb4d77b7afe0cb67326b35-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d34adb20714848f89cecc9d286b54d2b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d34adb20714848f89cecc9d286b54d2b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any positive integer n, if n is prime, then sum_of_digits(n) <= 2*sum_of_digits/num_divisors(n) + 0, with equality on 168 instances.
#
# Conjecture 2.  For any positive integer n, collatz_steps(n) >= 29/2*sqrt(collatz_steps)(n) + -105/2, with equality on 15 instances.
#
# Conjecture 3.  For any positive integer n, num_divisors(n) <= -4/3*sum_of_digits(n) + 48, with equality on 9 instances.
#
# Conjecture 4.  For any positive integer n, sum_of_digits(n) >= 21/10*sum_of_digits/num_divisors(n) + -11/10, with equality on 7 instances.
#
# Conjecture 5.  For any positive integer n, num_divisors(n) >= 1/10*sum_of_digits/num_divisors(n) + 9/10, with equality on 7 instances.
#
# Conjecture 6.  For any positive integer n, sum_of_digits(n) <= 1/4*num_divisors(n) + 25, with equality on 4 instances.
#
# Conjecture 7.  For any positive integer n, if n is even, then sum_of_digits(n) <= 12/7*sum_of_digits/num_divisors(n) + 150/7, with equality on 3 instances.
#
# Conjecture 8.  For any positive integer n, if n is even, then sum_of_digits(n) <= -1/8*num_divisors(n) + 53/2, with equality on 2 instances.
#
# Conjecture 9.  For any positive integer n, if n is prime, then sum_of_digits(n) <= -1/2*sqrt(collatz_steps)(n) + 57/2, with equality on 2 instances.
#
# Conjecture 10.  For any positive integer n, if n is even, then num_divisors(n) <= -32/7*sum_of_digits/num_divisors(n) + 236/7, with equality on 2 instances.
#
# Conjecture 11.  For any positive integer n, num_divisors(n) >= 1/10*sqrt(collatz_steps)(n) + 1, with equality on 2 instances.
#
# Conjecture 12.  For any positive integer n, collatz_steps(n) <= 4/3*sum_of_digits(n) + 470/3, with equality on 2 instances.
#
# Conjecture 13.  For any positive integer n, if n is even, then collatz_steps(n) <= 13*sqrt(collatz_steps)(n) + -12, with equality on 2 instances.
#
# Conjecture 14.  For any positive integer n, collatz_steps(n) <= 16/3*sum_of_digits/num_divisors(n) + 470/3, with equality on 2 instances.
#
# Conjecture 15.  For any positive integer n, if n is even, then collatz_steps(n) <= 12*sum_of_digits/num_divisors(n) + 243/2, with equality on 2 instances.
#
# Conjecture 16.  For any positive integer n, if n is prime, then collatz_steps(n) >= 1*sum_of_digits(n) + -1, with equality on 2 instances.
#
# Conjecture 17.  For any positive integer n, if n is even, then collatz_steps(n) >= 1/2*num_divisors(n) + 0, with equality on 2 instances.
#
# Conjecture 18.  For any positive integer n, collatz_steps(n) >= 15/7*sum_of_digits/num_divisors(n) + -15/7, with equality on 2 instances.
#
# Conjecture 19.  For any positive integer n, if n is prime, then collatz_steps(n) >= 2*sum_of_digits/num_divisors(n) + -1, with equality on 2 instances.
#
# Conjecture 20.  For any positive integer n, if n is prime and n is even, then sum_of_digits(n) <= 1*value(n) + 0, with equality on 1 instances.
