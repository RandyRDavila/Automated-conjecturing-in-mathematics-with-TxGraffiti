# %% [markdown]
# # Scale-Free Graph Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/scale_free_graphs.ipynb)
#
# ## Introduction
#
# This notebook demonstrates the application of the TxGraffiti algorithm to generate conjectures on scale-free graphs. Scale-free graphs are a type of graph characterized by the presence of hub nodes with a high degree of connectivity, and they are commonly found in natural and man-made systems, such as social networks and the internet.
#
# ## Dataset
#
# The dataset consists of randomly generated scale-free graphs and includes various numerical properties such as:
# - **Average Clustering Coefficient**: A measure of the degree to which nodes in a graph tend to cluster together.
# - **Degree Assortativity Coefficient**: A measure of the similarity of connections in the graph with respect to the node degree.
# - **Number of Triangles**: The number of triangles in the graph, indicating the presence of closely knit groups of nodes.
# - **Diameter**: The longest shortest path between any two nodes in the graph.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of scale-free graphs.
# - Identify significant relationships and patterns in graph properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to generate the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Explore the unique properties of scale-free graphs and discover new insights with TxGraffiti.

# %%
import pandas as pd
import numpy as np
import networkx as nx
from pulp import *
from fractions import Fraction
from itertools import combinations
import matplotlib.pyplot as plt

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="scale-free graph"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="G"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="G"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Generate synthetic data for scale-free graphs
n_samples = 1_000
np.random.seed(42)

# Generate scale-free graphs and convert them to simple graphs
graphs = [nx.Graph(nx.scale_free_graph(np.random.randint(10, 30))) for _ in range(n_samples)]

# Define properties
def avg_clustering_coefficient(G):
    return nx.average_clustering(G)

def degree_assortativity_coefficient(G):
    return nx.degree_assortativity_coefficient(G)

def number_of_triangles(G):
    return sum(nx.triangles(G).values()) // 3

def max_degree(G):
    return max(dict(G.degree()).values())

def average_shortest_path_length(G):
    if nx.is_connected(G):
        return nx.average_shortest_path_length(G)
    return np.nan

# Generate properties
avg_clustering = np.array([avg_clustering_coefficient(G) for G in graphs])
degree_assortativity = np.array([degree_assortativity_coefficient(G) for G in graphs])
num_triangles = np.array([number_of_triangles(G) for G in graphs])
max_degree_values = np.array([max_degree(G) for G in graphs])
avg_shortest_path = np.array([average_shortest_path_length(G) for G in graphs])

# Create the DataFrame
data = {
    'avg_clustering': avg_clustering,
    'degree_assortativity': degree_assortativity,
    'num_triangles': num_triangles,
    'max_degree': max_degree_values,
    'avg_shortest_path': avg_shortest_path
}
df = pd.DataFrame(data).dropna()  # Drop rows with NaN values

# Define the targets, invariants, and properties
targets = ["avg_clustering", "degree_assortativity", "num_triangles", "max_degree", "avg_shortest_path"]
invariants = ["avg_clustering", "degree_assortativity", "num_triangles", "max_degree", "avg_shortest_path"]
properties = []

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5fd3a57a2ff14938a57fb9137eee158d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5fd3a57a2ff14938a57fb9137eee158d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj 0 Primal inf 254.42235 (941) Dual inf 22.091754 (2) w.o. free dual inf (0)
# 2  Obj 512.73286
# 2  Obj -7.9799931e+11 Primal inf 6.9791851e+12 (522) Dual inf 4.8035603e+15 (2) w.o. free dual inf (1)
# 3  Obj 509.71519
# Optimal - objective value 509.71519
# After Postsolve, objective 509.71519, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 509.7151873 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/38280eaf33fc44a1a44ed435927d01bf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/38280eaf33fc44a1a44ed435927d01bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj 0 Primal inf 2.869349 (22) Dual inf 20.781905 (2) w.o. free dual inf (0)
# 3  Obj 455.46393
# Optimal - objective value 455.46393
# After Postsolve, objective 455.46393, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 455.4639286 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3d45b863212f4110891b0775685312e1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3d45b863212f4110891b0775685312e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj 0 Primal inf 2.2872917 (23) Dual inf 43.394203 (2) w.o. free dual inf (0)
# 2  Obj 512.73286
# 2  Obj 1.5279214e+13 Primal inf 1.947973e+10 (4) Dual inf 4.7687311e+13 (2) w.o. free dual inf (1)
# 3  Obj 478.1508
# Optimal - objective value 478.1508
# After Postsolve, objective 478.1508, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 478.1507983 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1d65b93de7e44eb9855b60b88f82a511-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1d65b93de7e44eb9855b60b88f82a511-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj 0 Primal inf 55.68005 (655) Dual inf 37.964242 (2) w.o. free dual inf (0)
# 4  Obj 381.48015
# Optimal - objective value 381.48015
# After Postsolve, objective 381.48015, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 381.4801467 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/77b1291c89b24e37863e735b9ecd7eb9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/77b1291c89b24e37863e735b9ecd7eb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 2  Obj 14.076328
# Optimal - objective value 14.076328
# After Postsolve, objective 14.076328, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 14.0763282 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f49212c9ba3a4c2badbac0a40a339adf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f49212c9ba3a4c2badbac0a40a339adf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 2  Obj 37.45991
# Optimal - objective value 37.45991
# After Postsolve, objective 37.45991, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 37.4599101 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7aa7465138c94178aff890cf6f1a09e1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7aa7465138c94178aff890cf6f1a09e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 2  Obj 15.290318
# Optimal - objective value 15.290318
# After Postsolve, objective 15.290318, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 15.29031774 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/49f38dbc0a054e07a03fe0d74499e2bb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/49f38dbc0a054e07a03fe0d74499e2bb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 3  Obj 18.084525
# Optimal - objective value 18.084525
# After Postsolve, objective 18.084525, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 18.08452529 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a98bbfb7b1294efe870ad5137fd4b5d7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a98bbfb7b1294efe870ad5137fd4b5d7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj 0 Primal inf 0.26016967 (3) Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 3  Obj 19.770713
# Optimal - objective value 19.770713
# After Postsolve, objective 19.770713, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 19.77071264 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b4820b772dd647e983672090aba41347-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b4820b772dd647e983672090aba41347-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj 0 Primal inf 0.049377795 (3) Dual inf 20.781905 (2) w.o. free dual inf (0)
# 3  Obj 11.677921
# Optimal - objective value 11.677921
# After Postsolve, objective 11.677921, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 11.6779212 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/52951c51c84d49868fe4a6478f1995b5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/52951c51c84d49868fe4a6478f1995b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj 0 Primal inf 0.028250002 (2) Dual inf 43.394203 (2) w.o. free dual inf (0)
# 5  Obj -120.82207
# Optimal - objective value -120.82207
# After Postsolve, objective -120.82207, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -120.8220697 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0a421aba704e4f1886ab2f1d8225c9ce-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0a421aba704e4f1886ab2f1d8225c9ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj 0 Primal inf 0.032530654 (3) Dual inf 37.964242 (2) w.o. free dual inf (0)
# 1  Obj 40.676558
# 1  Obj 4.8394738e+12 Primal inf 5.1526044e+10 (80) Dual inf 8.002061e+14 (2)
# 2  Obj 9.3695468e+12 Dual inf 3.7478177 (1)
# 4  Obj 71.090826 Dual inf 2360.9414 (1)
# 5  Obj -0.36169284
# Optimal - objective value -0.36169284
# After Postsolve, objective -0.36169284, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -0.3616928363 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/920e073f871f47bc91608c78514b8106-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/920e073f871f47bc91608c78514b8106-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj -0 Primal inf 1151.3067 (896) Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 6  Obj -784.56591
# Optimal - objective value -784.56591
# After Postsolve, objective -784.56591, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -784.5659057 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a17700b91deb491d9daff095a9c18620-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a17700b91deb491d9daff095a9c18620-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj -0 Primal inf 5.9056639 (22) Dual inf 20.781905 (2) w.o. free dual inf (0)
# 3  Obj -825.54604
# Optimal - objective value -825.54604
# After Postsolve, objective -825.54604, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -825.5460377 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6eb1f736a44d407997daf468e090d957-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6eb1f736a44d407997daf468e090d957-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj -0 Primal inf 4.6079614 (23) Dual inf 43.394203 (2) w.o. free dual inf (0)
# 3  Obj -825.37211
# Optimal - objective value -825.37211
# After Postsolve, objective -825.37211, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -825.3721125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/694188dfaeae486d84b04e7aded806f5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/694188dfaeae486d84b04e7aded806f5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj -0 Primal inf 148.86899 (652) Dual inf 37.964242 (2) w.o. free dual inf (0)
# 4  Obj -746.91246
# Optimal - objective value -746.91246
# After Postsolve, objective -746.91246, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -746.9124562 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/460bb3e8339a4005b1b8febd12f45f51-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/460bb3e8339a4005b1b8febd12f45f51-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj 0 Primal inf 12505.856 (898) Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 3  Obj 19957.345
# Optimal - objective value 19957.345
# After Postsolve, objective 19957.345, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 19957.3445 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3751f37600304389a89996b7bc233cbf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3751f37600304389a89996b7bc233cbf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj 0 Primal inf 8023.504 (941) Dual inf 22.091754 (2) w.o. free dual inf (0)
# 5  Obj 21781
# Optimal - objective value 21781
# After Postsolve, objective 21781, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 21781 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/62843d370ef642d389ba8b824a4e5be5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/62843d370ef642d389ba8b824a4e5be5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj 0 Primal inf 81.341931 (23) Dual inf 43.394203 (2) w.o. free dual inf (0)
# 3  Obj 18843.4
# Optimal - objective value 18843.4
# After Postsolve, objective 18843.4, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 18843.4 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ef7da699ff024a22a88177480c9131e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ef7da699ff024a22a88177480c9131e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj 0 Primal inf 1867.4753 (655) Dual inf 37.964242 (2) w.o. free dual inf (0)
# 3  Obj 21781
# Optimal - objective value 21781
# After Postsolve, objective 21781, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 21781 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/865fba2c831444e885484e2599b97b42-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/865fba2c831444e885484e2599b97b42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 2  Obj 947
# Optimal - objective value 947
# After Postsolve, objective 947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 947 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2394cd9a7322417bab0d79a8ba84f8f4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2394cd9a7322417bab0d79a8ba84f8f4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 2  Obj 947
# Optimal - objective value 947
# After Postsolve, objective 947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 947 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/43fc7ba042374b5a96f5e58b314aef5f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/43fc7ba042374b5a96f5e58b314aef5f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 2  Obj 947
# Optimal - objective value 947
# After Postsolve, objective 947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 947 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/96a1d9dbc22f4f87bbc5d2087cadc180-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/96a1d9dbc22f4f87bbc5d2087cadc180-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 2  Obj 947
# Optimal - objective value 947
# After Postsolve, objective 947, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 947 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/09cae128bb674a7e9550b20edcd1353c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/09cae128bb674a7e9550b20edcd1353c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj 0 Primal inf 28826.927 (898) Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 2  Obj 26516
# 2  Obj 1.8153713e+12 Primal inf 1.358601e+12 (231) Dual inf 3.0047549e+15 (2) w.o. free dual inf (1)
# 3  Obj 25409.988
# Optimal - objective value 25409.988
# After Postsolve, objective 25409.988, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 25409.9879 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fc75ae8c55d4174a3c6fc6fcf5ad34a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fc75ae8c55d4174a3c6fc6fcf5ad34a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj 0 Primal inf 17085.564 (941) Dual inf 22.091754 (2) w.o. free dual inf (0)
# 4  Obj 23428.578
# Optimal - objective value 23428.578
# After Postsolve, objective 23428.578, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 23428.57793 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a53b0749d3ae4b3d83485cc8f1fdf910-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a53b0749d3ae4b3d83485cc8f1fdf910-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj 0 Primal inf 175.48014 (22) Dual inf 20.781905 (2) w.o. free dual inf (0)
# 2  Obj 26516
# 2  Obj 8.5334524e+12 Primal inf 2.6020325e+10 (3) Dual inf 4.5793222e+13 (2) w.o. free dual inf (1)
# 3  Obj 25902.125
# Optimal - objective value 25902.125
# After Postsolve, objective 25902.125, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 25902.125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/859df6c9419c4f16b39194954b0cec47-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/859df6c9419c4f16b39194954b0cec47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj 0 Primal inf 3826.5514 (655) Dual inf 37.964242 (2) w.o. free dual inf (0)
# 3  Obj 23944.402
# Optimal - objective value 23944.402
# After Postsolve, objective 23944.402, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 23944.40243 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a83cd340af5344cfbfbbaf1f912ebb32-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a83cd340af5344cfbfbbaf1f912ebb32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 4  Obj 4735
# Optimal - objective value 4735
# After Postsolve, objective 4735, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4735 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7ad7426b2d074075b38f614d41ae93a8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7ad7426b2d074075b38f614d41ae93a8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 3  Obj 4735
# Optimal - objective value 4735
# After Postsolve, objective 4735, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4735 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0da614260aff41828b27b43129d08366-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0da614260aff41828b27b43129d08366-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 3  Obj 5104.1429
# Optimal - objective value 5104.1429
# After Postsolve, objective 5104.1429, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5104.142857 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2f92164c87674c8080b87d706ebdb560-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2f92164c87674c8080b87d706ebdb560-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 655 (-292) rows, 2 (0) columns and 1310 (-584) elements
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 37.964242 (2) w.o. free dual inf (0)
# 2  Obj 4735
# Optimal - objective value 4735
# After Postsolve, objective 4735, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4735 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5b06565ae7d14e5fb36db18cab570d0a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5b06565ae7d14e5fb36db18cab570d0a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj 0 Primal inf 5399.4991 (898) Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 2  Obj 2830.7065
# 2  Obj 2.2795713e+12 Primal inf 9.7656944e+11 (183) Dual inf 2.3607517e+15 (2) w.o. free dual inf (1)
# 4  Obj 2757.4381
# Optimal - objective value 2757.4381
# After Postsolve, objective 2757.4381, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2757.438053 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1315adbd7fbb432ebd21b0d19875a49b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1315adbd7fbb432ebd21b0d19875a49b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj 0 Primal inf 3287.4286 (941) Dual inf 22.091754 (2) w.o. free dual inf (0)
# 3  Obj 2830.7065
# 3  Obj -2.3113812e+13 Primal inf 3.1440182e+13 (891) Dual inf 6.6450805e+15 (2) w.o. free dual inf (1)
# 5  Obj 2774.6513
# Optimal - objective value 2774.6513
# After Postsolve, objective 2774.6513, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2774.651298 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab6b33a0d647469dbabc5fe23a9af1bc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab6b33a0d647469dbabc5fe23a9af1bc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj 0 Primal inf 21.974291 (22) Dual inf 20.781905 (2) w.o. free dual inf (0)
# 2  Obj 2830.7065
# 2  Obj 8.5334524e+12 Primal inf 2.6020325e+10 (3) Dual inf 4.5793222e+13 (2) w.o. free dual inf (1)
# 3  Obj 2796.6077
# Optimal - objective value 2796.6077
# After Postsolve, objective 2796.6077, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2796.607747 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/01981db2af9f4ad3b165b6d1dfc7116e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/01981db2af9f4ad3b165b6d1dfc7116e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj 0 Primal inf 16.872975 (23) Dual inf 43.394203 (2) w.o. free dual inf (0)
# 4  Obj 2830.2629
# Optimal - objective value 2830.2629
# After Postsolve, objective 2830.2629, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2830.262918 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/855af4930b2841c5898324ce84c9409f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/855af4930b2841c5898324ce84c9409f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 898 (-49) rows, 2 (0) columns and 1796 (-98) elements
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 3.5072593 (2) w.o. free dual inf (0)
# 5  Obj 1705.432
# Optimal - objective value 1705.432
# After Postsolve, objective 1705.432, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1705.43199 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a4a80f12dd044bb7896e0e8f2647bc56-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a4a80f12dd044bb7896e0e8f2647bc56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 941 (-6) rows, 2 (0) columns and 1882 (-12) elements
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 22.091754 (2) w.o. free dual inf (0)
# 3  Obj 1620.4222
# Optimal - objective value 1620.4222
# After Postsolve, objective 1620.4222, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1620.422222 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c727c8e7a4b54070a548ed3c8a281b8e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c727c8e7a4b54070a548ed3c8a281b8e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 22 (-925) rows, 2 (0) columns and 44 (-1850) elements
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 20.781905 (2) w.o. free dual inf (0)
# 3  Obj 1620.4222
# Optimal - objective value 1620.4222
# After Postsolve, objective 1620.4222, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1620.422222 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/36b3c50d94724f8386bc19007108eec6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/36b3c50d94724f8386bc19007108eec6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 952 COLUMNS
# At line 2849 RHS
# At line 3797 BOUNDS
# At line 3800 ENDATA
# Problem MODEL has 947 rows, 2 columns and 1894 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-924) rows, 2 (0) columns and 46 (-1848) elements
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 43.394203 (2) w.o. free dual inf (0)
# 3  Obj 1644.0307
# Optimal - objective value 1644.0307
# After Postsolve, objective 1644.0307, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1644.030655 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any scale-free graph G, num_triangles(G) <= -4/5*max_degree(G) + 153/5, with equality on 3 instances.
#
# Conjecture 2.  For any scale-free graph G, num_triangles(G) >= 1/6*max_degree(G) + -1/2, with equality on 3 instances.
#
# Conjecture 3.  For any scale-free graph G, max_degree(G) <= 1/7*num_triangles(G) + 141/7, with equality on 2 instances.
#
# Conjecture 4.  For any scale-free graph G, avg_clustering(G) <= -2/7*degree_assortativity(G) + 1/4, with equality on 0 instances.
#
# Conjecture 5.  For any scale-free graph G, avg_clustering(G) <= -1/7*avg_shortest_path(G) + 7/10, with equality on 0 instances.
#
# Conjecture 6.  For any scale-free graph G, avg_clustering(G) >= 1/10*avg_shortest_path(G) + -1/10, with equality on 0 instances.
#
# Conjecture 7.  For any scale-free graph G, degree_assortativity(G) <= -1/3*avg_clustering(G) + 0, with equality on 0 instances.
#
# Conjecture 8.  For any scale-free graph G, degree_assortativity(G) <= 5/8*avg_shortest_path(G) + -3/2, with equality on 0 instances.
#
# Conjecture 9.  For any scale-free graph G, degree_assortativity(G) >= 2/3*avg_clustering(G) + -9/10, with equality on 0 instances.
#
# Conjecture 10.  For any scale-free graph G, degree_assortativity(G) >= 2/5*avg_shortest_path(G) + -13/8, with equality on 0 instances.
#
# Conjecture 11.  For any scale-free graph G, num_triangles(G) <= 41/2*avg_shortest_path(G) + -265/9, with equality on 0 instances.
#
# Conjecture 12.  For any scale-free graph G, num_triangles(G) >= 133/10*avg_clustering(G) + -5/8, with equality on 0 instances.
#
# Conjecture 13.  For any scale-free graph G, max_degree(G) <= 105/2*avg_clustering(G) + 78/7, with equality on 0 instances.
#
# Conjecture 14.  For any scale-free graph G, max_degree(G) <= -61/2*degree_assortativity(G) + 61/9, with equality on 0 instances.
#
# Conjecture 15.  For any scale-free graph G, max_degree(G) <= -23/2*avg_shortest_path(G) + 275/6, with equality on 0 instances.
#
# Conjecture 16.  For any scale-free graph G, max_degree(G) >= -79/10*degree_assortativity(G) + 15/8, with equality on 0 instances.
#
# Conjecture 17.  For any scale-free graph G, max_degree(G) >= 4/9*num_triangles(G) + 14/5, with equality on 0 instances.
#
# Conjecture 18.  For any scale-free graph G, avg_shortest_path(G) <= -11/5*avg_clustering(G) + 22/7, with equality on 0 instances.
#
# Conjecture 19.  For any scale-free graph G, avg_shortest_path(G) <= -4/7*degree_assortativity(G) + 5/2, with equality on 0 instances.
#
# Conjecture 20.  For any scale-free graph G, avg_shortest_path(G) >= -8/9*avg_clustering(G) + 15/7, with equality on 0 instances.
