# %% [markdown]
# # Matrix Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/matrices.ipynb)
#
# ## Introduction
#
# This notebook applies the TxGraffiti algorithm to generate conjectures on square symmetric matrices. Matrices are fundamental in various areas of mathematics and applied sciences, including linear algebra, statistics, and machine learning. By examining the relationships between different matrix properties, TxGraffiti aims to uncover new mathematical insights and conjectures.
#
# ## Dataset
#
# The dataset consists of square symmetric matrices with various numerical properties such as:
# - **Numerical Properties**: Trace, determinant, second largest eigenvalue, Frobenius norm, condition number, and condition number times Frobenius norm.
# - **Boolean Properties**: Is positive definite, is sparse.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of square symmetric matrices.
# - Identify significant relationships and patterns in matrix properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to generate the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Explore the fascinating properties of square symmetric matrices and discover new mathematical conjectures with TxGraffiti.
#
# ---

# %%
# If running in Google Colab, you will need to pip install pulp.
# !pip install pulp

# Import the necessary libraries.
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="symmetric matrix"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="A"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w", upBound=10)
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="A"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w", upBound=10)
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Function to generate a square symmetric matrix
def generate_square_symmetric_matrix(size):
    A = np.random.rand(size, size)
    return (A + A.T) / 2

# Generate data for square symmetric matrices
n_samples = 1000
matrix_size = 20

data = []
for _ in range(n_samples):
    matrix = generate_square_symmetric_matrix(matrix_size)
    trace = np.trace(matrix)
    determinant = np.linalg.det(matrix)
    eigvals = np.linalg.eigvals(matrix)
    second_largest_eigenvalue = np.partition(eigvals, -2)[-2]
    frobenius_norm = np.linalg.norm(matrix, 'fro')
    condition_number = np.linalg.cond(matrix)
    condition_number_times_frobenius_norm = condition_number * frobenius_norm
    is_positive_definite = np.all(eigvals > 0)
    is_sparse = (np.count_nonzero(matrix) / (matrix_size**2)) < 0.5
    data.append([trace, determinant, second_largest_eigenvalue, frobenius_norm, condition_number, is_positive_definite, is_sparse, condition_number_times_frobenius_norm])

columns = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number", "is_positive_definite", "is_sparse", "condition_number_times_frobenius_norm"]
df = pd.DataFrame(data, columns=columns)

# Define the targets, invariants, and properties
targets = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number"]
invariants = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number", "condition_number_times_frobenius_norm"]
properties = ["is_positive_definite", "is_sparse"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Requirement already satisfied: pulp in /opt/anaconda3/lib/python3.11/site-packages (2.9.0)
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a95de0db5b2a4f14821b1d02bafd44c6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a95de0db5b2a4f14821b1d02bafd44c6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 1503976 (1000) Dual inf 0.095034005 (2) w.o. free dual inf (0)
# 2  Obj 14302.788
# 2  Obj 8.903522e+10 Primal inf 3.1748361e+13 (490) Dual inf 1.1605035e+15 (2) w.o. free dual inf (1)
# 3  Obj 14300.148
# Optimal - objective value 14300.148
# Optimal objective 14300.14753 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf81b24d6a5f4cd5a26dfa4e485b7974-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf81b24d6a5f4cd5a26dfa4e485b7974-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b611ba9527a540f1b653b5f927e83171-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b611ba9527a540f1b653b5f927e83171-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e27bde5afbdb43aa941584bd21ed5b20-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e27bde5afbdb43aa941584bd21ed5b20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bc68d76f9bb644ffa6767bb76ab8447c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/bc68d76f9bb644ffa6767bb76ab8447c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 6314.146 (1000) Dual inf 27.810788 (2) w.o. free dual inf (0)
# 3  Obj 14129.792
# Optimal - objective value 14129.792
# Optimal objective 14129.7922 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/25e61c3a4b054b0aa8b0c240a56b7eea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/25e61c3a4b054b0aa8b0c240a56b7eea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e2ab9cd8edb54bd09df3298a5ee47d4a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e2ab9cd8edb54bd09df3298a5ee47d4a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad8b650522824dc0ad1051162be58918-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad8b650522824dc0ad1051162be58918-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9193a2fed1cb4cdf9b2bc18c6b1faa9e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9193a2fed1cb4cdf9b2bc18c6b1faa9e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 921.75783 (1000) Dual inf 209.4883 (2) w.o. free dual inf (0)
# 4  Obj 13754.415
# Optimal - objective value 13754.415
# Optimal objective 13754.41529 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/414e30f885b240b48a5e0275adaab3ea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/414e30f885b240b48a5e0275adaab3ea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/53565c26f5454f63b8c893fc36091a65-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/53565c26f5454f63b8c893fc36091a65-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b73ce7851d8242cc8de0fea470f9bb78-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b73ce7851d8242cc8de0fea470f9bb78-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6709d16290bf4831a4c2a46e9ee20923-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6709d16290bf4831a4c2a46e9ee20923-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 626.71282 (1000) Dual inf 874.59116 (2) w.o. free dual inf (0)
# 2  Obj 14302.788
# 2  Obj 2.3380286e+14 Primal inf 7.6676905e+12 (770) Dual inf 1.3623752e+16 (2) w.o. free dual inf (1)
# 3  Obj 14292.766
# Optimal - objective value 14292.766
# Optimal objective 14292.76565 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/37b01539f8944738989e651194e57d48-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/37b01539f8944738989e651194e57d48-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4570326129014b89bfa0f89e7ff766b2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4570326129014b89bfa0f89e7ff766b2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/121bda0b455b40008c1b4b5f9b072ca1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/121bda0b455b40008c1b4b5f9b072ca1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7f5e73771e74481bb5e6c2d9f96c89f1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7f5e73771e74481bb5e6c2d9f96c89f1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 190.39971 (1000) Dual inf 2861.7467 (2) w.o. free dual inf (0)
# 2  Obj 14302.788
# 2  Obj 7.3929818e+14 Primal inf 8.2858182e+12 (778) Dual inf 1.402214e+16 (2) w.o. free dual inf (1)
# 3  Obj 14293.186
# Optimal - objective value 14293.186
# Optimal objective 14293.18578 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9a4ba2e2a7e543f59bd57e9bdcc1d70c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9a4ba2e2a7e543f59bd57e9bdcc1d70c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00a3ef14ef0a41e384c7995196ca078c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00a3ef14ef0a41e384c7995196ca078c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fe5c030a95554459a7622a4459581d16-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fe5c030a95554459a7622a4459581d16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c9868de04d5d47f19f401920bbf6e00f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c9868de04d5d47f19f401920bbf6e00f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 0.095034005 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 0.095034005 (2) w.o. free dual inf (0)
# 2  Obj 6353.4971
# Optimal - objective value 6353.4971
# Optimal objective 6353.49711 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3a76ae9a1f444b3b9bdee94d9a1c488f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3a76ae9a1f444b3b9bdee94d9a1c488f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cd1a9c77603a4d7b857f64f6b53d8637-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cd1a9c77603a4d7b857f64f6b53d8637-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/89b6d270b0dd4a71b470ff22bcc02228-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/89b6d270b0dd4a71b470ff22bcc02228-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c5504f2368db449da1f0f6c186c8ca4d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c5504f2368db449da1f0f6c186c8ca4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 27.810788 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 27.810788 (2) w.o. free dual inf (0)
# 2  Obj 6651.3423
# Optimal - objective value 6651.3423
# Optimal objective 6651.342305 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8bc72b4ebfb747b0826a45c5ba9b19c0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8bc72b4ebfb747b0826a45c5ba9b19c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0409b0bb771e481da352b33d09373752-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0409b0bb771e481da352b33d09373752-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6f3b5fe7102d4eaf99cbe3f8ec8c8d7b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6f3b5fe7102d4eaf99cbe3f8ec8c8d7b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6a0ac6e8648140caad4d02e5a2b7e2bf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6a0ac6e8648140caad4d02e5a2b7e2bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 209.4883 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 209.4883 (2) w.o. free dual inf (0)
# 2  Obj 6662.964
# Optimal - objective value 6662.964
# Optimal objective 6662.96404 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fba41673086406197e682142e6d755c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fba41673086406197e682142e6d755c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/90d3bd0d5b0241028b392d7e3f2c376a-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/90d3bd0d5b0241028b392d7e3f2c376a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5537603a8efb4a4b90290a663330ea13-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5537603a8efb4a4b90290a663330ea13-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8d3a21091dcd4f0c8cbcdb5d8fb2bedc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8d3a21091dcd4f0c8cbcdb5d8fb2bedc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 874.59116 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 874.59116 (2) w.o. free dual inf (0)
# 2  Obj 6330.2625
# Optimal - objective value 6330.2625
# Optimal objective 6330.262496 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6cad34359a9f4320914319a504a20782-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6cad34359a9f4320914319a504a20782-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/90d48a94b00b4e98b7612e8d1e8397c2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/90d48a94b00b4e98b7612e8d1e8397c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a424d2c952f044c09e2fbe2e1b69898d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a424d2c952f044c09e2fbe2e1b69898d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1464c86d8a474e6cad700792d5211d1b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1464c86d8a474e6cad700792d5211d1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 2861.7467 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 2861.7467 (2) w.o. free dual inf (0)
# 2  Obj 6330.2854
# Optimal - objective value 6330.2854
# Optimal objective 6330.28542 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/55a12c2d11da4daaa3470e2be951ca73-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/55a12c2d11da4daaa3470e2be951ca73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5c5c86fb054a414782bf0af74e19b67c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5c5c86fb054a414782bf0af74e19b67c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/408f8dc69f8843d7a067d45511157f39-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/408f8dc69f8843d7a067d45511157f39-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/66e6b403c3ff462f82e96af11d0faddc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/66e6b403c3ff462f82e96af11d0faddc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 0.028780275 (489) Dual inf 163.12055 (2) w.o. free dual inf (0)
# 3  Obj 20.168652
# Optimal - objective value 20.168652
# Optimal objective 20.16865171 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1b1e35714e894bd3a640d081dc9751c8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1b1e35714e894bd3a640d081dc9751c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3aa71e3ebe8843429f8dccf3ed1a03c6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3aa71e3ebe8843429f8dccf3ed1a03c6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d862c6a7868e4eaead2b5d89ff726a9f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d862c6a7868e4eaead2b5d89ff726a9f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d7864600cfc643f6a45bb37254647087-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d7864600cfc643f6a45bb37254647087-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 0.17062316 (491) Dual inf 27.810788 (2) w.o. free dual inf (0)
# 1  Obj 19.362413
# 1  Obj 2.1436349e+12 Primal inf 1.6432589e+11 (189) Dual inf 1.8906573e+15 (2)
# 2  Obj 7.6595405e+12 Dual inf 3.0638161 (1)
# 4  Obj 22.496892 Dual inf 2135.2741 (1)
# 5  Obj 15.898899
# Optimal - objective value 15.898899
# Optimal objective 15.89889869 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/61170e69edb34e0c9074f645e2fa7eb7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/61170e69edb34e0c9074f645e2fa7eb7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4adc4da80a5d496e85dc8e6628e6d33e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4adc4da80a5d496e85dc8e6628e6d33e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c4a4a2eb7fb64c00949346d33beb94a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c4a4a2eb7fb64c00949346d33beb94a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2fb7c8a7b2064dd3a6f2dec4e99468a8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2fb7c8a7b2064dd3a6f2dec4e99468a8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 0.025624545 (487) Dual inf 209.4883 (2) w.o. free dual inf (0)
# 3  Obj 20.701164
# Optimal - objective value 20.701164
# Optimal objective 20.70116427 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# ...
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/93d3d5af600640c790db33cebff1b1eb-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/93d3d5af600640c790db33cebff1b1eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 0.095034005 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 0.095034005 (2) w.o. free dual inf (0)
# 2  Obj 57518.675
# Optimal - objective value 57518.675
# Optimal objective 57518.67507 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e5ef4ec7dcdf4c6f925ed3abbb5a2ee2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e5ef4ec7dcdf4c6f925ed3abbb5a2ee2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/78c738fa9c2f455fbfac186df4a746e9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/78c738fa9c2f455fbfac186df4a746e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8b51e98f8ede42388fac09f2e887a9b8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8b51e98f8ede42388fac09f2e887a9b8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9d85c794ddf940f1876486d8cc52e8e8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9d85c794ddf940f1876486d8cc52e8e8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 27.810788 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 27.810788 (2) w.o. free dual inf (0)
# 4  Obj 59505.087
# Optimal - objective value 59505.087
# Optimal objective 59505.08686 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cd880dfdd9424ec8b6922fbbb0498901-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cd880dfdd9424ec8b6922fbbb0498901-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/61c740baf5f341748b279bd361ff7e43-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/61c740baf5f341748b279bd361ff7e43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad4798d158fc4b54bd305f9f1159385e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad4798d158fc4b54bd305f9f1159385e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00cd345b2f834711a98a0d62fe719667-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/00cd345b2f834711a98a0d62fe719667-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 209.4883 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 209.4883 (2) w.o. free dual inf (0)
# 3  Obj 60081.827
# Optimal - objective value 60081.827
# Optimal objective 60081.82655 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5a9574482ce549118c8744bf236e1737-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5a9574482ce549118c8744bf236e1737-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/07c18de09abd4ca29f6d92f955538553-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/07c18de09abd4ca29f6d92f955538553-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/276bc0409cb2420db3eaacaf0ecc43b2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/276bc0409cb2420db3eaacaf0ecc43b2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d638bcdb8bd9455ebcdcb036b09f35fa-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d638bcdb8bd9455ebcdcb036b09f35fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 2861.7467 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 2861.7467 (2) w.o. free dual inf (0)
# 7  Obj 1167566.1
# Optimal - objective value 1167566.1
# Optimal objective 1167566.074 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f1e569a76e974d27811cf88dff5ab9d6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f1e569a76e974d27811cf88dff5ab9d6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/39075e7d344a490c89950ad64e74a75d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/39075e7d344a490c89950ad64e74a75d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/10fc66392fce4b2d85671f9bb976c310-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/10fc66392fce4b2d85671f9bb976c310-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any symmetric matrix A, condition_number(A) <= -586156/9*trace(A) + 4660492/5, with equality on 1 instances.
#
# Conjecture 2.  For any symmetric matrix A, condition_number(A) <= -19895708*determinant(A) + 2490941/6, with equality on 1 instances.
#
# Conjecture 3.  For any symmetric matrix A, condition_number(A) <= -2057065/3*second_largest_eigenvalue(A) + 2929197/2, with equality on 1 instances.
#
# Conjecture 4.  For any symmetric matrix A, condition_number(A) <= -4404164/9*frobenius_norm(A) + 28428066/5, with equality on 1 instances.
#
# Conjecture 5.  For any symmetric matrix A, trace(A) <= -1151/10*determinant(A) + 143/10, with equality on 0 instances.
#
# Conjecture 6.  For any symmetric matrix A, trace(A) <= 39/8*second_largest_eigenvalue(A) + 32/5, with equality on 0 instances.
#
# Conjecture 7.  For any symmetric matrix A, trace(A) <= 11/10*frobenius_norm(A) + 9/5, with equality on 0 instances.
#
# Conjecture 8.  For any symmetric matrix A, trace(A) >= 151/2*determinant(A) + 19/3, with equality on 0 instances.
#
# Conjecture 9.  For any symmetric matrix A, trace(A) >= 8/5*second_largest_eigenvalue(A) + 41/10, with equality on 0 instances.
#
# Conjecture 10.  For any symmetric matrix A, trace(A) >= 1*frobenius_norm(A) + -35/8, with equality on 0 instances.
#
# Conjecture 11.  For any symmetric matrix A, second_largest_eigenvalue(A) <= -111/7*determinant(A) + 17/8, with equality on 0 instances.
#
# Conjecture 12.  For any symmetric matrix A, second_largest_eigenvalue(A) <= -2/5*frobenius_norm(A) + 58/9, with equality on 0 instances.
#
# Conjecture 13.  For any symmetric matrix A, second_largest_eigenvalue(A) >= 99/4*determinant(A) + 6/5, with equality on 0 instances.
#
# Conjecture 14.  For any symmetric matrix A, second_largest_eigenvalue(A) >= 1/6*frobenius_norm(A) + -1/2, with equality on 0 instances.
#
# Conjecture 15.  For any symmetric matrix A, frobenius_norm(A) <= 1/10*trace(A) + 32/3, with equality on 0 instances.
#
# Conjecture 16.  For any symmetric matrix A, frobenius_norm(A) <= 33/2*determinant(A) + 104/9, with equality on 0 instances.
#
# Conjecture 17.  For any symmetric matrix A, frobenius_norm(A) <= -1*second_largest_eigenvalue(A) + 119/9, with equality on 0 instances.
#
# Conjecture 18.  For any symmetric matrix A, frobenius_norm(A) >= 51/8*determinant(A) + 91/9, with equality on 0 instances.
#
# Conjecture 19.  For any symmetric matrix A, frobenius_norm(A) >= 1/7*second_largest_eigenvalue(A) + 89/9, with equality on 0 instances.
#
# Conjecture 20.  For any symmetric matrix A, condition_number(A) >= -2/9*trace(A) + 359/6, with equality on 0 instances.
