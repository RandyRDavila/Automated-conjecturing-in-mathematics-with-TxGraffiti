# %% [markdown]
# # Matrix Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/matrices.ipynb)
#
# ## Introduction
#
# This notebook applies the TxGraffiti algorithm to generate conjectures on square symmetric matrices. Matrices are fundamental in various areas of mathematics and applied sciences, including linear algebra, statistics, and machine learning. By examining the relationships between different matrix properties, TxGraffiti aims to uncover new mathematical insights and conjectures.
#
# ## Dataset
#
# The dataset consists of square symmetric matrices with various numerical properties such as:
# - **Numerical Properties**: Trace, determinant, second largest eigenvalue, Frobenius norm, condition number, and condition number times Frobenius norm.
# - **Boolean Properties**: Is positive definite, is sparse.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of square symmetric matrices.
# - Identify significant relationships and patterns in matrix properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to generate the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Explore the fascinating properties of square symmetric matrices and discover new mathematical conjectures with TxGraffiti.
#
# ---

# %%
# If running in Google Colab, you will need to pip install pulp.
# !pip install pulp

# Import the necessary libraries.
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="symmetric matrix"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="A"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="A"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Function to generate a square symmetric matrix
def generate_square_symmetric_matrix(size):
    A = np.random.rand(size, size)
    return (A + A.T) / 2

# Generate data for square symmetric matrices
n_samples = 1000
matrix_size = 20

data = []
for _ in range(n_samples):
    matrix = generate_square_symmetric_matrix(matrix_size)
    trace = np.trace(matrix)
    determinant = np.linalg.det(matrix)
    eigvals = np.linalg.eigvals(matrix)
    second_largest_eigenvalue = np.partition(eigvals, -2)[-2]
    frobenius_norm = np.linalg.norm(matrix, 'fro')
    condition_number = np.linalg.cond(matrix)
    condition_number_times_frobenius_norm = condition_number * frobenius_norm
    is_positive_definite = np.all(eigvals > 0)
    is_sparse = (np.count_nonzero(matrix) / (matrix_size**2)) < 0.5
    data.append([trace, determinant, second_largest_eigenvalue, frobenius_norm, condition_number, is_positive_definite, is_sparse, condition_number_times_frobenius_norm])

columns = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number", "is_positive_definite", "is_sparse", "condition_number_times_frobenius_norm"]
df = pd.DataFrame(data, columns=columns)

# Define the targets, invariants, and properties
targets = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number"]
invariants = ["trace", "determinant", "second_largest_eigenvalue", "frobenius_norm", "condition_number", "condition_number_times_frobenius_norm"]
properties = ["is_positive_definite", "is_sparse"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6e1fc22200fa4680a7a76f2cf11248c7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6e1fc22200fa4680a7a76f2cf11248c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 1496274.1 (1000) Dual inf 0.16155665 (2) w.o. free dual inf (0)
# 2  Obj 14098.704
# 2  Obj -3.350753e+11 Primal inf 5.2718281e+13 (548) Dual inf 3.4812983e+15 (2) w.o. free dual inf (1)
# 3  Obj 14088.034
# Optimal - objective value 14088.034
# Optimal objective 14088.03432 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/268b86af119247a4bbe867ceaa145ae1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/268b86af119247a4bbe867ceaa145ae1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fc79954670f4c58813dbb2591e99561-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fc79954670f4c58813dbb2591e99561-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7063bcb9f9164e7bb42ad35791b5954f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7063bcb9f9164e7bb42ad35791b5954f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a763c0aba5dd44e793e30cb4d0a0d389-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a763c0aba5dd44e793e30cb4d0a0d389-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 6320.7492 (1000) Dual inf 27.972257 (2) w.o. free dual inf (0)
# 5  Obj 13606.77
# Optimal - objective value 13606.77
# Optimal objective 13606.77044 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c39d97a10e20443798240c4675b074bf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c39d97a10e20443798240c4675b074bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c3f31037d07b4b63a897c3e2191d0893-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c3f31037d07b4b63a897c3e2191d0893-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5f6bd1bb28874b858b8a07335c3fc55e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5f6bd1bb28874b858b8a07335c3fc55e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/59e2ed94e01b4f73a9d699b1c344f572-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/59e2ed94e01b4f73a9d699b1c344f572-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 922.02638 (1000) Dual inf 207.12536 (2) w.o. free dual inf (0)
# 4  Obj 13266.237
# Optimal - objective value 13266.237
# Optimal objective 13266.23732 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e3d5166162a3477cb5e843d364140b63-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e3d5166162a3477cb5e843d364140b63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fbc5cfef8d744989a05be4023265852-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1fbc5cfef8d744989a05be4023265852-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5f65fc1dd1cc4b1882dfbf2cc7c65599-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5f65fc1dd1cc4b1882dfbf2cc7c65599-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e0bc7086fed84e6099aabb048377f28e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e0bc7086fed84e6099aabb048377f28e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 634.10854 (1000) Dual inf 704.89729 (2) w.o. free dual inf (0)
# 2  Obj 14098.704
# 2  Obj 4.6545167e+14 Primal inf 2.3044528e+12 (474) Dual inf 6.4100918e+15 (2) w.o. free dual inf (1)
# 3  Obj 14082.329
# Optimal - objective value 14082.329
# Optimal objective 14082.3293 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3d633c890273489b8a2881b2549138ff-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3d633c890273489b8a2881b2549138ff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/eeec777998be4b189ac9071e4d4779b1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/eeec777998be4b189ac9071e4d4779b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/02b1ec14f15e4f9fae208de8d433fdaa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/02b1ec14f15e4f9fae208de8d433fdaa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/589b739332754fa69777082f6427a4c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/589b739332754fa69777082f6427a4c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 192.70075 (1000) Dual inf 2313.7014 (2) w.o. free dual inf (0)
# 2  Obj 14098.704
# 2  Obj 1.5125636e+15 Primal inf 2.6763486e+12 (505) Dual inf 6.9316392e+15 (2) w.o. free dual inf (1)
# 3  Obj 14082.515
# Optimal - objective value 14082.515
# Optimal objective 14082.51537 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c1f9099e961a4b1a9c3335425f873ad4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c1f9099e961a4b1a9c3335425f873ad4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3e07403d9a5b40f49e540f5bfd3c02a9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3e07403d9a5b40f49e540f5bfd3c02a9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/60e5b7c85a1f4242b686d7f2202fce06-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/60e5b7c85a1f4242b686d7f2202fce06-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6157932776664f39a8a16fba5a58438d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6157932776664f39a8a16fba5a58438d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 0.16155665 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 0.16155665 (2) w.o. free dual inf (0)
# 2  Obj 5645.5626
# Optimal - objective value 5645.5626
# Optimal objective 5645.56258 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c0c32bc7012342fc9a002ab3f9790b7f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c0c32bc7012342fc9a002ab3f9790b7f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1f67aef70bb94c988fed573d740c9a4d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1f67aef70bb94c988fed573d740c9a4d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/63d56df9fd9d4066ba936f8b21940409-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/63d56df9fd9d4066ba936f8b21940409-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/771f133b30ae4b81b973be757d2290ed-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/771f133b30ae4b81b973be757d2290ed-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 27.972257 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 27.972257 (2) w.o. free dual inf (0)
# 2  Obj 6501.4916
# Optimal - objective value 6501.4916
# Optimal objective 6501.491553 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5ecc94b22b7f46ecb587541c8016045e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5ecc94b22b7f46ecb587541c8016045e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd940c6b9559409f85bcdb0e6dd0bdf9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dd940c6b9559409f85bcdb0e6dd0bdf9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2e9d66a892a6450c906e7564fc30012b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2e9d66a892a6450c906e7564fc30012b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8356ddbc6a43f6882d9ccd9e46ae5c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cf8356ddbc6a43f6882d9ccd9e46ae5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 207.12536 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 207.12536 (2) w.o. free dual inf (0)
# 2  Obj 6037.8437
# Optimal - objective value 6037.8437
# Optimal objective 6037.843683 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/033c95076bd44ec6b2e17e201d69699c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/033c95076bd44ec6b2e17e201d69699c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0f3af66c68a2469fab5903bf0806b2ea-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/0f3af66c68a2469fab5903bf0806b2ea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b2ac2e43f61048dc9c185a9173d0f4f3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b2ac2e43f61048dc9c185a9173d0f4f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4a5d713a65394c889177c6e6fd19db5c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4a5d713a65394c889177c6e6fd19db5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 704.89729 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 704.89729 (2) w.o. free dual inf (0)
# 2  Obj 5668.3143
# Optimal - objective value 5668.3143
# Optimal objective 5668.31425 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f343dc17b154403183dbc708707e0b6d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f343dc17b154403183dbc708707e0b6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/305d66965c2e4f8782303df9b12323f2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/305d66965c2e4f8782303df9b12323f2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad0ec751cf214bb291e79fac4d082610-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ad0ec751cf214bb291e79fac4d082610-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31f074ec77f446c092d654f8201eecd5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/31f074ec77f446c092d654f8201eecd5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 2313.7014 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 2313.7014 (2) w.o. free dual inf (0)
# 2  Obj 5669.0969
# Optimal - objective value 5669.0969
# Optimal objective 5669.096871 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/75bf053f347346348a3d95fccfb3cb5c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/75bf053f347346348a3d95fccfb3cb5c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4de9f3d4dbc4410290f1baf1cdc04a36-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4de9f3d4dbc4410290f1baf1cdc04a36-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/254152c039e341038bb7980296a22db4-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/254152c039e341038bb7980296a22db4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4abe20c68c22415e87c92a724753556b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4abe20c68c22415e87c92a724753556b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 0.026651855 (477) Dual inf 156.20551 (2) w.o. free dual inf (0)
# 4  Obj 11.344236
# Optimal - objective value 11.344236
# Optimal objective 11.34423604 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6a775a4977b94ebbbc5ce5556ed9e01c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6a775a4977b94ebbbc5ce5556ed9e01c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/611e35aeb9924eebbc7183a3664ebb88-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/611e35aeb9924eebbc7183a3664ebb88-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/64c96e074d504b7da2e2d24aac066716-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/64c96e074d504b7da2e2d24aac066716-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value 0
# Optimal objective 0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8fb1b730208345d895119ee9a79c2336-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8fb1b730208345d895119ee9a79c2336-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj 0 Primal inf 0.16191565 (480) Dual inf 27.972257 (2) w.o. free dual inf (0)
# 1  Obj 15.200361
# 1  Obj 1.281491e+12 Primal inf 3.1952202e+11 (304) Dual inf 3.0412781e+15 (2)
# 2  Obj 7.3671667e+12 Dual inf 2.9468666 (1)
# 4  Obj 13.339817
# Optimal - objective value 13.339817
# Optimal objective 13.33981656 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# ...
# 0  Obj -0 Dual inf 0.16155665 (2) w.o. free dual inf (0)
# 3  Obj 44346.829
# Optimal - objective value 44346.829
# Optimal objective 44346.82904 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/87dde577cadb4451a29a6e42e5cccd59-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/87dde577cadb4451a29a6e42e5cccd59-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/65135a984cce4c768aab18d51e817005-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/65135a984cce4c768aab18d51e817005-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cb15278e1eee4c9599771dde00dd0efe-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cb15278e1eee4c9599771dde00dd0efe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/35a85b1834a44075b3de7fb08d602457-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/35a85b1834a44075b3de7fb08d602457-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 27.972257 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 27.972257 (2) w.o. free dual inf (0)
# 2  Obj 43899.088
# Optimal - objective value 43899.088
# Optimal objective 43899.08815 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4e9bcd618f98417482ab923abfb820db-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4e9bcd618f98417482ab923abfb820db-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/659ea346f0fe47d0b7b8b02547f7a582-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/659ea346f0fe47d0b7b8b02547f7a582-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/176213e942d94d2c90b1ebbd30958623-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/176213e942d94d2c90b1ebbd30958623-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f62a6cb390424a2daa28a88eab782d03-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/f62a6cb390424a2daa28a88eab782d03-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 207.12536 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 207.12536 (2) w.o. free dual inf (0)
# 2  Obj 46293.012
# Optimal - objective value 46293.012
# Optimal objective 46293.01177 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/da00f2e425fd4f26ab48e76673f1b560-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/da00f2e425fd4f26ab48e76673f1b560-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/67fce969253944ee83659283e848d891-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/67fce969253944ee83659283e848d891-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a3989ba6f8a0432388cde1b9a1b30639-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a3989ba6f8a0432388cde1b9a1b30639-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a77220def88a4c82ab9bca1f815c1249-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a77220def88a4c82ab9bca1f815c1249-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1005 COLUMNS
# At line 3008 RHS
# At line 4009 BOUNDS
# At line 4012 ENDATA
# Problem MODEL has 1000 rows, 2 columns and 2000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1000 (0) rows, 2 (0) columns and 2000 (0) elements
# 0  Obj -0 Dual inf 2313.7014 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 2313.7014 (2) w.o. free dual inf (0)
# 7  Obj 1053310.6
# Optimal - objective value 1053310.6
# Optimal objective 1053310.553 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/748a427bc5444f53b71c3202ff82a243-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/748a427bc5444f53b71c3202ff82a243-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1584dbfae86446e6821ff3f6df9353fe-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/1584dbfae86446e6821ff3f6df9353fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/03c4a48348e04decabc0408d6006cf47-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/03c4a48348e04decabc0408d6006cf47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5 COLUMNS
# At line 7 RHS
# At line 8 BOUNDS
# At line 10 ENDATA
# Problem MODEL has 0 rows, 1 columns and 0 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Empty problem - 0 rows, 1 columns and 0 elements
# Optimal - objective value -0
# Optimal objective -0 - 0 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any symmetric matrix A, condition_number(A) <= 140918*second_largest_eigenvalue(A) + -986176/7, with equality on 2 instances.
#
# Conjecture 2.  For any symmetric matrix A, condition_number(A) <= 175778/7*trace(A) + -564909/4, with equality on 1 instances.
#
# Conjecture 3.  For any symmetric matrix A, condition_number(A) <= 14463387/2*determinant(A) + 463827/4, with equality on 1 instances.
#
# Conjecture 4.  For any symmetric matrix A, condition_number(A) <= -942553/7*frobenius_norm(A) + 7825624/5, with equality on 1 instances.
#
# Conjecture 5.  For any symmetric matrix A, trace(A) <= 1679/10*determinant(A) + 141/10, with equality on 0 instances.
#
# Conjecture 6.  For any symmetric matrix A, trace(A) <= 20/3*second_largest_eigenvalue(A) + 31/10, with equality on 0 instances.
#
# Conjecture 7.  For any symmetric matrix A, trace(A) <= 2*frobenius_norm(A) + -8, with equality on 0 instances.
#
# Conjecture 8.  For any symmetric matrix A, trace(A) >= -1397/4*determinant(A) + 45/8, with equality on 0 instances.
#
# Conjecture 9.  For any symmetric matrix A, trace(A) >= 3*second_largest_eigenvalue(A) + 12/7, with equality on 0 instances.
#
# Conjecture 10.  For any symmetric matrix A, trace(A) >= 9/10*frobenius_norm(A) + -34/9, with equality on 0 instances.
#
# Conjecture 11.  For any symmetric matrix A, second_largest_eigenvalue(A) <= 193/8*determinant(A) + 21/10, with equality on 0 instances.
#
# Conjecture 12.  For any symmetric matrix A, second_largest_eigenvalue(A) <= -1/8*frobenius_norm(A) + 7/2, with equality on 0 instances.
#
# Conjecture 13.  For any symmetric matrix A, second_largest_eigenvalue(A) >= 145/7*determinant(A) + 11/9, with equality on 0 instances.
#
# Conjecture 14.  For any symmetric matrix A, frobenius_norm(A) <= -26*determinant(A) + 93/8, with equality on 0 instances.
#
# Conjecture 15.  For any symmetric matrix A, frobenius_norm(A) <= 1/3*second_largest_eigenvalue(A) + 11, with equality on 0 instances.
#
# Conjecture 16.  For any symmetric matrix A, frobenius_norm(A) >= 1/8*trace(A) + 69/8, with equality on 0 instances.
#
# Conjecture 17.  For any symmetric matrix A, frobenius_norm(A) >= -308/9*determinant(A) + 99/10, with equality on 0 instances.
#
# Conjecture 18.  For any symmetric matrix A, frobenius_norm(A) >= 5/8*second_largest_eigenvalue(A) + 89/10, with equality on 0 instances.
#
# Conjecture 19.  For any symmetric matrix A, condition_number(A) >= 25/9*trace(A) + 71/5, with equality on 0 instances.
#
# Conjecture 20.  For any symmetric matrix A, condition_number(A) >= -5717/9*determinant(A) + 443/10, with equality on 0 instances.
