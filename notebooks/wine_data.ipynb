# %% [markdown]
# # Wine Data Conjectures with TxGraffiti
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/RandyRDavila/AI-discovery-in-mathematics-with-TxGraffiti/blob/main/notebooks/wine_data.ipynb)
#
# ## Introduction
#
# This notebook applies the TxGraffiti algorithm to generate conjectures on the wine quality dataset. The wine quality dataset, commonly used in machine learning, includes various chemical properties of wines that can be used to predict their quality. By applying TxGraffiti, we aim to discover new relationships and patterns within this dataset.
#
# ## Dataset
#
# The dataset consists of wine samples and includes various numerical properties such as:
# - **Numerical Properties**: Fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, and quality.
# - **Boolean Properties**: High acidity, high sugar, high alcohol, high pH, and high quality.
#
# ## Objectives
#
# - Generate conjectures relating different numerical properties of wines.
# - Identify significant relationships and patterns in wine properties.
# - Apply the Theo and Static Dalmatian heuristics to filter and refine the conjectures.
#
# ## Usage
#
# 1. **Run the cells to load the dataset and apply TxGraffiti.**
# 2. **Examine the generated conjectures and their significance.**
#
# Discover new insights into wine properties and quality with TxGraffiti.
#
# ---

# %%
# If running in Google Colab, you will need to pip install pulp.
# !pip install pulp

# Import the necessary libraries.
import pandas as pd
import numpy as np
from pulp import *
from fractions import Fraction
from itertools import combinations

# Define the hypothesis, conclusion, and conjecture classes
class Hypothesis:
    def __init__(self, statements):
        self.statements = statements

class LinearConclusion:
    def __init__(self, target, inequality, slope, other, intercept):
        self.target = target
        self.inequality = inequality
        self.slope = slope
        self.other = other
        self.intercept = intercept

class LinearConjecture:
    def __init__(self, hypothesis, conclusion, symbol, touch, type="vino"):
        self.hypothesis = hypothesis
        self.conclusion = conclusion
        self.symbol = symbol
        self.touch = touch
        self.type = type

    def __repr__(self):
        if self.hypothesis.statements:
            hypothesis_str = " and ".join([f"{self.symbol} is {h}" for h in self.hypothesis.statements])
            return (f"For any {self.type} {self.symbol}, if {hypothesis_str}, then "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")
        else:
            return (f"For any {self.type} {self.symbol}, "
                    f"{self.conclusion.target}({self.symbol}) {self.conclusion.inequality} "
                    f"{self.conclusion.slope}*{self.conclusion.other}({self.symbol}) + "
                    f"{self.conclusion.intercept}, with equality on {self.touch} instances.")

    def get_sharp_objects(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        sharp_indices = df[np.isclose(Y, float(self.conclusion.slope) * X + float(self.conclusion.intercept))].index
        return df.loc[sharp_indices]

    def calculate_distances(self, df):
        X = df[self.conclusion.other].to_numpy()
        Y = df[self.conclusion.target].to_numpy()
        distances = np.abs(Y - (float(self.conclusion.slope) * X + float(self.conclusion.intercept)))
        return distances

def make_upper_linear_conjecture(df, target, other, hypothesis, symbol="W"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("UpperBoundConjecture", LpMinimize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y >= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, "<=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_lower_linear_conjecture(df, target, other, hypothesis, symbol="W"):
    for hyp in hypothesis:
        df = df[df[hyp] == True]
    X = df[other].to_numpy()
    Y = df[target].to_numpy()

    prob = LpProblem("LowerBoundConjecture", LpMaximize)
    w = LpVariable("w")
    b = LpVariable("b")

    prob += lpSum([w * x + b - y for x, y in zip(X, Y)])

    for x, y in zip(X, Y):
        prob += w * x + b - y <= 0

    prob.solve()

    if w.varValue is None or b.varValue is None:
        return None

    m = Fraction(w.varValue).limit_denominator(10)
    b = Fraction(b.varValue).limit_denominator(10)
    if m == 0:
        return None  # Skip trivial conjectures

    touch = np.sum(np.isclose(Y, float(m) * X + float(b)))

    hypothesis = Hypothesis(hypothesis)
    conclusion = LinearConclusion(target, ">=", m, other, b)

    return LinearConjecture(hypothesis, conclusion, symbol, touch)

def make_all_upper_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_upper_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def make_all_lower_linear_conjectures(df, target, others, properties):
    conjectures = []
    for other in others:
        for k in range(4):  # Considering hypotheses of none, one, two, and three boolean properties
            for prop_comb in combinations(properties, k):
                if other != target:
                    conjecture = make_lower_linear_conjecture(df, target, other, prop_comb)
                    if conjecture:
                        conjectures.append(conjecture)
    return conjectures

def sort_by_touch_number(conjectures):
    return sorted(conjectures, key=lambda x: x.touch, reverse=True)

def apply_theo_heuristic(conjectures):
    filtered_conjectures = []
    for conj_1 in conjectures:
        is_general = True
        for conj_2 in filtered_conjectures:
            if (conj_1.conclusion.slope == conj_2.conclusion.slope and
                conj_1.conclusion.intercept == conj_2.conclusion.intercept and
                conj_1.conclusion.inequality == conj_2.conclusion.inequality and
                set(conj_1.hypothesis.statements).issubset(set(conj_2.hypothesis.statements))):
                is_general = False
                break
        if is_general:
            filtered_conjectures.append(conj_1)
    return filtered_conjectures

def apply_static_dalmatian_heuristic(df, conjectures):
    filtered_conjectures = []
    for conj in conjectures:
        conj_distances = conj.calculate_distances(df)
        keep_conj = True
        for other_conj in filtered_conjectures:
            other_distances = other_conj.calculate_distances(df)
            if np.all(conj_distances >= other_distances):
                keep_conj = False
                break
        if keep_conj:
            filtered_conjectures.append(conj)
    return filtered_conjectures

def txgraffiti_conjecture_generation(df, targets, invariants, properties):
    conjectures = []
    for target in targets:
        upper_conjectures = make_all_upper_linear_conjectures(df, target, invariants, properties)
        lower_conjectures = make_all_lower_linear_conjectures(df, target, invariants, properties)
        conjectures += upper_conjectures + lower_conjectures

    conjectures = sort_by_touch_number(conjectures)
    conjectures = apply_theo_heuristic(conjectures)
    conjectures = apply_static_dalmatian_heuristic(df, conjectures)

    return conjectures

# Load the wine quality dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(url, sep=';')

# Define boolean properties based on some thresholds
df['high_acidity'] = df['fixed acidity'] > df['fixed acidity'].median()
df['high_sugar'] = df['residual sugar'] > df['residual sugar'].median()
df['high_alcohol'] = df['alcohol'] > df['alcohol'].median()
df['high_pH'] = df['pH'] > df['pH'].median()
df['high_quality'] = df['quality'] > df['quality'].median()

# Define the targets, invariants, and properties
targets = ["quality", "volatile acidity", "chlorides"]
invariants = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]
properties = ["high_acidity", "high_sugar", "high_alcohol", "high_pH", "high_quality"]

# Generate conjectures using the TxGraffiti algorithm
conjectures = txgraffiti_conjecture_generation(df, targets, invariants, properties)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c435d920c5274f2dbbb884c66c7a4b19-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c435d920c5274f2dbbb884c66c7a4b19-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1604 COLUMNS
# At line 4805 RHS
# At line 6405 BOUNDS
# At line 6408 ENDATA
# Problem MODEL has 1599 rows, 2 columns and 3198 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 96 (-1503) rows, 2 (0) columns and 192 (-3006) elements
# 0  Obj 0 Primal inf 76.213316 (96) Dual inf 206.585 (2) w.o. free dual inf (0)
# 4  Obj 12792
# Optimal - objective value 12792
# After Postsolve, objective 12792, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12792 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3ac56ea0c6ab4f809a069fefc43726bd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3ac56ea0c6ab4f809a069fefc43726bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 788 COLUMNS
# At line 2357 RHS
# At line 3141 BOUNDS
# At line 3144 ENDATA
# Problem MODEL has 783 rows, 2 columns and 1566 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 63 (-720) rows, 2 (0) columns and 126 (-1440) elements
# 0  Obj 0 Primal inf 39.526754 (63) Dual inf 138.404 (2) w.o. free dual inf (0)
# 3  Obj 6264
# Optimal - objective value 6264
# After Postsolve, objective 6264, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6264 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab31d8ab5cee4da88a8d74f5296fefce-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ab31d8ab5cee4da88a8d74f5296fefce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 721 COLUMNS
# At line 2156 RHS
# At line 2873 BOUNDS
# At line 2876 ENDATA
# Problem MODEL has 716 rows, 2 columns and 1432 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 84 (-632) rows, 2 (0) columns and 168 (-1264) elements
# 0  Obj 0 Primal inf 61.417158 (84) Dual inf 96.135998 (2) w.o. free dual inf (0)
# 3  Obj 5728
# Optimal - objective value 5728
# After Postsolve, objective 5728, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5728 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5823b7c705404298bd0613fa7418314b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5823b7c705404298bd0613fa7418314b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 762 COLUMNS
# At line 2279 RHS
# At line 3037 BOUNDS
# At line 3040 ENDATA
# Problem MODEL has 757 rows, 2 columns and 1514 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 89 (-668) rows, 2 (0) columns and 178 (-1336) elements
# 0  Obj 0 Primal inf 72.60438 (89) Dual inf 97.568998 (2) w.o. free dual inf (0)
# 4  Obj 6056
# Optimal - objective value 6056
# After Postsolve, objective 6056, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6056 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fa7de3b358784638ae28c3b2acaedd9a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/fa7de3b358784638ae28c3b2acaedd9a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 782 COLUMNS
# At line 2339 RHS
# At line 3117 BOUNDS
# At line 3120 ENDATA
# Problem MODEL has 777 rows, 2 columns and 1554 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 58 (-719) rows, 2 (0) columns and 116 (-1438) elements
# 0  Obj 0 Primal inf 53.962845 (58) Dual inf 92.336998 (2) w.o. free dual inf (0)
# 3  Obj 6216
# Optimal - objective value 6216
# After Postsolve, objective 6216, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6216 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/432d5b90897342c289532083a657489b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/432d5b90897342c289532083a657489b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 222 COLUMNS
# At line 659 RHS
# At line 877 BOUNDS
# At line 880 ENDATA
# Problem MODEL has 217 rows, 2 columns and 434 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 67 (-150) rows, 2 (0) columns and 134 (-300) elements
# 0  Obj 0 Primal inf 57.990201 (67) Dual inf 29.830998 (2) w.o. free dual inf (0)
# 4  Obj 1736
# Optimal - objective value 1736
# After Postsolve, objective 1736, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1736 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/325941c07c91415a9bddc68d136daf27-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/325941c07c91415a9bddc68d136daf27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 428 COLUMNS
# At line 1277 RHS
# At line 1701 BOUNDS
# At line 1704 ENDATA
# Problem MODEL has 423 rows, 2 columns and 846 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 59 (-364) rows, 2 (0) columns and 118 (-728) elements
# 0  Obj 0 Primal inf 36.108684 (59) Dual inf 75.625998 (2) w.o. free dual inf (0)
# 4  Obj 3384
# Optimal - objective value 3384
# After Postsolve, objective 3384, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3384 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/29b7293f982945a4aa01589a985d35cc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/29b7293f982945a4aa01589a985d35cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 374 COLUMNS
# At line 1115 RHS
# At line 1485 BOUNDS
# At line 1488 ENDATA
# Problem MODEL has 369 rows, 2 columns and 738 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 56 (-313) rows, 2 (0) columns and 112 (-626) elements
# 0  Obj 0 Primal inf 36.081753 (56) Dual inf 65.860998 (2) w.o. free dual inf (0)
# 3  Obj 2952
# Optimal - objective value 2952
# After Postsolve, objective 2952, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2952 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c2af41af29804c0eb09fad7bd88fd3b8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c2af41af29804c0eb09fad7bd88fd3b8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 168 COLUMNS
# At line 497 RHS
# At line 661 BOUNDS
# At line 664 ENDATA
# Problem MODEL has 163 rows, 2 columns and 326 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-138) rows, 2 (0) columns and 50 (-276) elements
# 0  Obj 0 Primal inf 17.699561 (25) Dual inf 27.426998 (2) w.o. free dual inf (0)
# 3  Obj 1291.7
# Optimal - objective value 1291.7
# After Postsolve, objective 1291.7, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1291.7 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e5d05d65de7c4f1ea48e84e2a8708e1e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e5d05d65de7c4f1ea48e84e2a8708e1e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 143 COLUMNS
# At line 422 RHS
# At line 561 BOUNDS
# At line 564 ENDATA
# Problem MODEL has 138 rows, 2 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 43 (-95) rows, 2 (0) columns and 86 (-190) elements
# 0  Obj 0 Primal inf 30.298878 (43) Dual inf 24.817998 (2) w.o. free dual inf (0)
# 3  Obj 1104
# Optimal - objective value 1104
# After Postsolve, objective 1104, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1104 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e3fa4383cb334076a94ad5d4fc8cbb48-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e3fa4383cb334076a94ad5d4fc8cbb48-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 389 COLUMNS
# At line 1160 RHS
# At line 1545 BOUNDS
# At line 1548 ENDATA
# Problem MODEL has 384 rows, 2 columns and 768 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 79 (-305) rows, 2 (0) columns and 158 (-610) elements
# 0  Obj 0 Primal inf 58.756612 (79) Dual inf 51.430998 (2) w.o. free dual inf (0)
# 3  Obj 3072
# Optimal - objective value 3072
# After Postsolve, objective 3072, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3072 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/36b43569ed0d48aba9e19a3ad4ed0cba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/36b43569ed0d48aba9e19a3ad4ed0cba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 335 COLUMNS
# At line 998 RHS
# At line 1329 BOUNDS
# At line 1332 ENDATA
# Problem MODEL has 330 rows, 2 columns and 660 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 49 (-281) rows, 2 (0) columns and 98 (-562) elements
# 0  Obj 0 Primal inf 41.214303 (49) Dual inf 40.478998 (2) w.o. free dual inf (0)
# 3  Obj 2590.2581
# Optimal - objective value 2590.2581
# After Postsolve, objective 2590.2581, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2590.258065 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9941d694acc24468b78a4eaf9201223e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9941d694acc24468b78a4eaf9201223e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 117 COLUMNS
# At line 344 RHS
# At line 457 BOUNDS
# At line 460 ENDATA
# Problem MODEL has 112 rows, 2 columns and 224 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 48 (-64) rows, 2 (0) columns and 96 (-128) elements
# 0  Obj 0 Primal inf 37.4547 (48) Dual inf 17.582998 (2) w.o. free dual inf (0)
# 3  Obj 896
# Optimal - objective value 896
# After Postsolve, objective 896, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 896 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7b00a7ceb4e34a14a9c736b1863768af-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7b00a7ceb4e34a14a9c736b1863768af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 434 COLUMNS
# At line 1295 RHS
# At line 1725 BOUNDS
# At line 1728 ENDATA
# Problem MODEL has 429 rows, 2 columns and 858 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 56 (-373) rows, 2 (0) columns and 112 (-746) elements
# 0  Obj 0 Primal inf 52.657656 (56) Dual inf 50.506998 (2) w.o. free dual inf (0)
# 3  Obj 3432
# Optimal - objective value 3432
# After Postsolve, objective 3432, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3432 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d82ae59cef96436bae0f82474636b253-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d82ae59cef96436bae0f82474636b253-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 195 COLUMNS
# At line 578 RHS
# At line 769 BOUNDS
# At line 772 ENDATA
# Problem MODEL has 190 rows, 2 columns and 380 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 63 (-127) rows, 2 (0) columns and 126 (-254) elements
# 0  Obj 0 Primal inf 55.181077 (63) Dual inf 25.892998 (2) w.o. free dual inf (0)
# 3  Obj 1520
# Optimal - objective value 1520
# After Postsolve, objective 1520, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1520 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/db8994292655454c9aa50aaa2b395f8b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/db8994292655454c9aa50aaa2b395f8b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 94 COLUMNS
# At line 275 RHS
# At line 365 BOUNDS
# At line 368 ENDATA
# Problem MODEL has 89 rows, 2 columns and 178 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 37 (-52) rows, 2 (0) columns and 74 (-104) elements
# 0  Obj 0 Primal inf 37.311101 (37) Dual inf 10.960998 (2) w.o. free dual inf (0)
# 3  Obj 712
# Optimal - objective value 712
# After Postsolve, objective 712, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 712 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b0b496f72a0f4d2b860b7e0d710cf5ab-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b0b496f72a0f4d2b860b7e0d710cf5ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 213 COLUMNS
# At line 632 RHS
# At line 841 BOUNDS
# At line 844 ENDATA
# Problem MODEL has 208 rows, 2 columns and 416 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 54 (-154) rows, 2 (0) columns and 108 (-308) elements
# 0  Obj 0 Primal inf 33.578008 (54) Dual inf 37.822998 (2) w.o. free dual inf (0)
# 4  Obj 1664
# Optimal - objective value 1664
# After Postsolve, objective 1664, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1664 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cc23173cd3904989aaf7f317dc49b708-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/cc23173cd3904989aaf7f317dc49b708-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 320 RHS
# At line 425 BOUNDS
# At line 428 ENDATA
# Problem MODEL has 104 rows, 2 columns and 208 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 24 (-80) rows, 2 (0) columns and 48 (-160) elements
# 0  Obj 0 Primal inf 16.32781 (24) Dual inf 17.535998 (2) w.o. free dual inf (0)
# 2  Obj 728
# Optimal - objective value 728
# After Postsolve, objective 728, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 728 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/51167569eb6e49d98c3d67b4d18fe6e0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/51167569eb6e49d98c3d67b4d18fe6e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 86 COLUMNS
# At line 251 RHS
# At line 333 BOUNDS
# At line 336 ENDATA
# Problem MODEL has 81 rows, 2 columns and 162 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 34 (-47) rows, 2 (0) columns and 68 (-94) elements
# 0  Obj 0 Primal inf 23.561406 (34) Dual inf 14.814998 (2) w.o. free dual inf (0)
# 3  Obj 648
# Optimal - objective value 648
# After Postsolve, objective 648, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 648 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4237d52027114dc3aec74b2a7b1c3362-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/4237d52027114dc3aec74b2a7b1c3362-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 94 COLUMNS
# At line 275 RHS
# At line 365 BOUNDS
# At line 368 ENDATA
# Problem MODEL has 89 rows, 2 columns and 178 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 23 (-66) rows, 2 (0) columns and 46 (-132) elements
# 0  Obj 0 Primal inf 16.558307 (23) Dual inf 14.982998 (2) w.o. free dual inf (0)
# 3  Obj 705.03333
# Optimal - objective value 705.03333
# After Postsolve, objective 705.03333, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 705.0333333 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d497eeeb18c14cde85af13b4c5d253d8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d497eeeb18c14cde85af13b4c5d253d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 128 COLUMNS
# At line 377 RHS
# At line 501 BOUNDS
# At line 504 ENDATA
# Problem MODEL has 123 rows, 2 columns and 246 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 40 (-83) rows, 2 (0) columns and 80 (-166) elements
# 0  Obj 0 Primal inf 28.637293 (40) Dual inf 21.873998 (2) w.o. free dual inf (0)
# 3  Obj 984
# Optimal - objective value 984
# After Postsolve, objective 984, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 984 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/30350225be094420844f35ea258c721e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/30350225be094420844f35ea258c721e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 33 COLUMNS
# At line 92 RHS
# At line 121 BOUNDS
# At line 124 ENDATA
# Problem MODEL has 28 rows, 2 columns and 56 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 14 (-14) rows, 2 (0) columns and 28 (-28) elements
# 0  Obj 0 Primal inf 10.938576 (14) Dual inf 4.744998 (2) w.o. free dual inf (0)
# 3  Obj 220.76667
# Optimal - objective value 220.76667
# After Postsolve, objective 220.76667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 220.7666667 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2288ea94dae444a1ac3dcaf6fe3ed549-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2288ea94dae444a1ac3dcaf6fe3ed549-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 208 COLUMNS
# At line 617 RHS
# At line 821 BOUNDS
# At line 824 ENDATA
# Problem MODEL has 203 rows, 2 columns and 406 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 43 (-160) rows, 2 (0) columns and 86 (-320) elements
# 0  Obj 0 Primal inf 37.762369 (43) Dual inf 24.528998 (2) w.o. free dual inf (0)
# 3  Obj 1569.4194
# Optimal - objective value 1569.4194
# After Postsolve, objective 1569.4194, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1569.419355 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a3c45f05644c4e758d1c81c50998085a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/a3c45f05644c4e758d1c81c50998085a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 320 RHS
# At line 425 BOUNDS
# At line 428 ENDATA
# Problem MODEL has 104 rows, 2 columns and 208 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 45 (-59) rows, 2 (0) columns and 90 (-118) elements
# 0  Obj 0 Primal inf 35.256445 (45) Dual inf 16.239998 (2) w.o. free dual inf (0)
# 3  Obj 832
# Optimal - objective value 832
# After Postsolve, objective 832, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 832 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/60d756ec8a3244dab0ccb72350b17363-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/60d756ec8a3244dab0ccb72350b17363-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 128 RHS
# At line 169 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 40 rows, 2 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 21 (-19) rows, 2 (0) columns and 42 (-38) elements
# 0  Obj 0 Primal inf 18.57438 (21) Dual inf 5.762998 (2) w.o. free dual inf (0)
# 2  Obj 320
# 2  Obj 1.075e+11 Primal inf 2.6459864e+10 (10) Dual inf 1.1068979e+14 (2) w.o. free dual inf (1)
# 6  Obj 318.83784
# Optimal - objective value 318.83784
# After Postsolve, objective 318.83784, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 318.8378378 - 6 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/048d6b41c692426798f4d255f11a57c0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/048d6b41c692426798f4d255f11a57c0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 85 COLUMNS
# At line 248 RHS
# At line 329 BOUNDS
# At line 332 ENDATA
# Problem MODEL has 80 rows, 2 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 35 (-45) rows, 2 (0) columns and 70 (-90) elements
# 0  Obj 0 Primal inf 35.394331 (35) Dual inf 9.852998 (2) w.o. free dual inf (0)
# 3  Obj 640
# Optimal - objective value 640
# After Postsolve, objective 640, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 640 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5e6b9f9d4ef74684a51faa5245cf5a4e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/5e6b9f9d4ef74684a51faa5245cf5a4e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1604 COLUMNS
# At line 4805 RHS
# At line 6405 BOUNDS
# At line 6408 ENDATA
# Problem MODEL has 1599 rows, 2 columns and 3198 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 143 (-1456) rows, 2 (0) columns and 286 (-2912) elements
# 0  Obj 0 Primal inf 1207.7941 (143) Dual inf 12.253481 (2) w.o. free dual inf (0)
# 3  Obj 12792
# Optimal - objective value 12792
# After Postsolve, objective 12792, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 12792 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dc7f319f7ad340a2b2eb9e26c89a542e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/dc7f319f7ad340a2b2eb9e26c89a542e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 788 COLUMNS
# At line 2357 RHS
# At line 3141 BOUNDS
# At line 3144 ENDATA
# Problem MODEL has 783 rows, 2 columns and 1566 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 117 (-666) rows, 2 (0) columns and 234 (-1332) elements
# 0  Obj 0 Primal inf 999.68262 (117) Dual inf 6.0285649 (2) w.o. free dual inf (0)
# 3  Obj 6264
# Optimal - objective value 6264
# After Postsolve, objective 6264, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6264 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9137de3eccf54667899a437496707095-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9137de3eccf54667899a437496707095-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 721 COLUMNS
# At line 2156 RHS
# At line 2873 BOUNDS
# At line 2876 ENDATA
# Problem MODEL has 716 rows, 2 columns and 1432 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 116 (-600) rows, 2 (0) columns and 232 (-1200) elements
# 0  Obj 0 Primal inf 962.24761 (116) Dual inf 6.3563094 (2) w.o. free dual inf (0)
# 3  Obj 5728
# Optimal - objective value 5728
# After Postsolve, objective 5728, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 5728 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c941c690fc8c403f9395636cbe70780a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c941c690fc8c403f9395636cbe70780a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 762 COLUMNS
# At line 2279 RHS
# At line 3037 BOUNDS
# At line 3040 ENDATA
# Problem MODEL has 757 rows, 2 columns and 1514 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 115 (-642) rows, 2 (0) columns and 230 (-1284) elements
# 0  Obj 0 Primal inf 1029.2037 (115) Dual inf 5.571056 (2) w.o. free dual inf (0)
# 3  Obj 6056
# Optimal - objective value 6056
# After Postsolve, objective 6056, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6056 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d7d3088f4f6843f1af5a74e9c7ad354d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d7d3088f4f6843f1af5a74e9c7ad354d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 782 COLUMNS
# At line 2339 RHS
# At line 3117 BOUNDS
# At line 3120 ENDATA
# Problem MODEL has 777 rows, 2 columns and 1554 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 128 (-649) rows, 2 (0) columns and 256 (-1298) elements
# 0  Obj 0 Primal inf 1047.4742 (128) Dual inf 6.1531543 (2) w.o. free dual inf (0)
# 3  Obj 6216
# Optimal - objective value 6216
# After Postsolve, objective 6216, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6216 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/19699fa22d974cb298a01e7f7a134fd4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/19699fa22d974cb298a01e7f7a134fd4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 222 COLUMNS
# At line 659 RHS
# At line 877 BOUNDS
# At line 880 ENDATA
# Problem MODEL has 217 rows, 2 columns and 434 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 56 (-161) rows, 2 (0) columns and 112 (-322) elements
# 0  Obj 0 Primal inf 631.64619 (56) Dual inf 1.6716748 (2) w.o. free dual inf (0)
# 3  Obj 1736
# Optimal - objective value 1736
# After Postsolve, objective 1736, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1736 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6e89ea8f13ff4c999aea6cbd10f12c3f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/6e89ea8f13ff4c999aea6cbd10f12c3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 428 COLUMNS
# At line 1277 RHS
# At line 1701 BOUNDS
# At line 1704 ENDATA
# Problem MODEL has 423 rows, 2 columns and 846 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 96 (-327) rows, 2 (0) columns and 192 (-654) elements
# 0  Obj 0 Primal inf 810.10596 (96) Dual inf 3.8859517 (2) w.o. free dual inf (0)
# 3  Obj 3384
# Optimal - objective value 3384
# After Postsolve, objective 3384, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3384 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/024abd688e114daaa8c8e071a0ead687-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/024abd688e114daaa8c8e071a0ead687-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 374 COLUMNS
# At line 1115 RHS
# At line 1485 BOUNDS
# At line 1488 ENDATA
# Problem MODEL has 369 rows, 2 columns and 738 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 77 (-292) rows, 2 (0) columns and 154 (-584) elements
# 0  Obj 0 Primal inf 737.2315 (77) Dual inf 2.652404 (2) w.o. free dual inf (0)
# 3  Obj 2952
# Optimal - objective value 2952
# After Postsolve, objective 2952, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2952 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ac4a756611e34b95b0ffa1cceea73a6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/ac4a756611e34b95b0ffa1cceea73a6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 168 COLUMNS
# At line 497 RHS
# At line 661 BOUNDS
# At line 664 ENDATA
# Problem MODEL has 163 rows, 2 columns and 326 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 71 (-92) rows, 2 (0) columns and 142 (-184) elements
# 0  Obj 0 Primal inf 597.3691 (71) Dual inf 1.3085402 (2) w.o. free dual inf (0)
# 2  Obj 1304
# 2  Obj 3.756754e+11 Primal inf 1.2320509e+11 (22) Dual inf 2.7110177e+14 (2) w.o. free dual inf (1)
# 3  Obj 1246.8681
# Optimal - objective value 1246.8681
# After Postsolve, objective 1246.8681, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1246.868132 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/63674e7d793746ea9699910c59a99466-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/63674e7d793746ea9699910c59a99466-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 143 COLUMNS
# At line 422 RHS
# At line 561 BOUNDS
# At line 564 ENDATA
# Problem MODEL has 138 rows, 2 columns and 276 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 40 (-98) rows, 2 (0) columns and 80 (-196) elements
# 0  Obj 0 Primal inf 477.11968 (40) Dual inf 1.0766646 (2) w.o. free dual inf (0)
# 3  Obj 1104
# Optimal - objective value 1104
# After Postsolve, objective 1104, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1104 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7fd3662526c1450f9de934c39a6bc725-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/7fd3662526c1450f9de934c39a6bc725-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 389 COLUMNS
# At line 1160 RHS
# At line 1545 BOUNDS
# At line 1548 ENDATA
# Problem MODEL has 384 rows, 2 columns and 768 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 88 (-296) rows, 2 (0) columns and 176 (-592) elements
# 0  Obj 0 Primal inf 779.08602 (88) Dual inf 3.2899391 (2) w.o. free dual inf (0)
# 3  Obj 3072
# Optimal - objective value 3072
# After Postsolve, objective 3072, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3072 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2c21e3b66a0f49c8ad990fad2e4662f1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/2c21e3b66a0f49c8ad990fad2e4662f1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 335 COLUMNS
# At line 998 RHS
# At line 1329 BOUNDS
# At line 1332 ENDATA
# Problem MODEL has 330 rows, 2 columns and 660 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 98 (-232) rows, 2 (0) columns and 196 (-464) elements
# 0  Obj 0 Primal inf 797.1579 (98) Dual inf 3.0497332 (2) w.o. free dual inf (0)
# 2  Obj 2640
# 2  Obj 4.478326e+09 Primal inf 3.0108594e+11 (39) Dual inf 4.9235125e+14 (2) w.o. free dual inf (1)
# 3  Obj 2639.2778
# Optimal - objective value 2639.2778
# After Postsolve, objective 2639.2778, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2639.277778 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d318ad58bf7e4ef1821328c2121c2926-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/d318ad58bf7e4ef1821328c2121c2926-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 117 COLUMNS
# At line 344 RHS
# At line 457 BOUNDS
# At line 460 ENDATA
# Problem MODEL has 112 rows, 2 columns and 224 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 42 (-70) rows, 2 (0) columns and 84 (-140) elements
# 0  Obj 0 Primal inf 299.99996 (42) Dual inf 1.6917242 (2) w.o. free dual inf (0)
# 3  Obj 896
# Optimal - objective value 896
# After Postsolve, objective 896, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 896 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 434 COLUMNS
# At line 1295 RHS
# At line 1725 BOUNDS
# At line 1728 ENDATA
# Problem MODEL has 429 rows, 2 columns and 858 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 38 (-391) rows, 2 (0) columns and 76 (-782) elements
# 0  Obj -0 Dual inf 92.850331 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 92.850331 (2) w.o. free dual inf (0)
# 2  Obj 16.056275
# Optimal - objective value 16.056275
# After Postsolve, objective 16.056275, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 16.05627451 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b9a64911b7e441628ae6cd378106f672-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/b9a64911b7e441628ae6cd378106f672-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 195 COLUMNS
# At line 578 RHS
# At line 769 BOUNDS
# At line 772 ENDATA
# Problem MODEL has 190 rows, 2 columns and 380 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 35 (-155) rows, 2 (0) columns and 70 (-310) elements
# 0  Obj -0 Dual inf 41.894165 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 41.894165 (2) w.o. free dual inf (0)
# 2  Obj 2.4110145
# Optimal - objective value 2.4110145
# After Postsolve, objective 2.4110145, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2.411014493 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c0306f01ddb94fcaa6d73633bdc4e783-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/c0306f01ddb94fcaa6d73633bdc4e783-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 94 COLUMNS
# At line 275 RHS
# At line 365 BOUNDS
# At line 368 ENDATA
# Problem MODEL has 89 rows, 2 columns and 178 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 32 (-57) rows, 2 (0) columns and 64 (-114) elements
# 0  Obj -0 Dual inf 18.898165 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 18.898165 (2) w.o. free dual inf (0)
# 3  Obj 4.1749825
# Optimal - objective value 4.1749825
# After Postsolve, objective 4.1749825, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4.174982456 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/484ced7b6e224cd789a3b0fb33f3c35f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/484ced7b6e224cd789a3b0fb33f3c35f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 213 COLUMNS
# At line 632 RHS
# At line 841 BOUNDS
# At line 844 ENDATA
# Problem MODEL has 208 rows, 2 columns and 416 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 32 (-176) rows, 2 (0) columns and 64 (-352) elements
# 0  Obj -0 Dual inf 45.171998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 45.171998 (2) w.o. free dual inf (0)
# 3  Obj 11.1272
# Optimal - objective value 11.1272
# After Postsolve, objective 11.1272, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 11.1272 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/12780d4920c74919a8c4a73027357e88-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/12780d4920c74919a8c4a73027357e88-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 320 RHS
# At line 425 BOUNDS
# At line 428 ENDATA
# Problem MODEL has 104 rows, 2 columns and 208 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 34 (-70) rows, 2 (0) columns and 68 (-140) elements
# 0  Obj -0 Dual inf 19.897998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 19.897998 (2) w.o. free dual inf (0)
# 4  Obj 6.1869231
# Optimal - objective value 6.1869231
# After Postsolve, objective 6.1869231, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 6.186923077 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e68f1d624ab542478fdb00e6376ce517-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/e68f1d624ab542478fdb00e6376ce517-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 86 COLUMNS
# At line 251 RHS
# At line 333 BOUNDS
# At line 336 ENDATA
# Problem MODEL has 81 rows, 2 columns and 162 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 30 (-51) rows, 2 (0) columns and 60 (-102) elements
# 0  Obj -0 Dual inf 17.240998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 17.240998 (2) w.o. free dual inf (0)
# 4  Obj 4.4593636
# Optimal - objective value 4.4593636
# After Postsolve, objective 4.4593636, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4.459363636 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9cd867c73f4943b7a4114240f994029c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/9cd867c73f4943b7a4114240f994029c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 94 COLUMNS
# At line 275 RHS
# At line 365 BOUNDS
# At line 368 ENDATA
# Problem MODEL has 89 rows, 2 columns and 178 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 25 (-64) rows, 2 (0) columns and 50 (-128) elements
# 0  Obj -0 Dual inf 19.167998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 19.167998 (2) w.o. free dual inf (0)
# 2  Obj 3.915037
# Optimal - objective value 3.915037
# After Postsolve, objective 3.915037, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3.915037037 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8076644f9ad34190bc644a1401a896f3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8076644f9ad34190bc644a1401a896f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 128 COLUMNS
# At line 377 RHS
# At line 501 BOUNDS
# At line 504 ENDATA
# Problem MODEL has 123 rows, 2 columns and 246 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 29 (-94) rows, 2 (0) columns and 58 (-188) elements
# 0  Obj -0 Dual inf 26.957998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 26.957998 (2) w.o. free dual inf (0)
# 2  Obj 4.8513529
# Optimal - objective value 4.8513529
# After Postsolve, objective 4.8513529, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 4.851352941 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3b3247d4a8414c738ee5b68d60499aae-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3b3247d4a8414c738ee5b68d60499aae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 33 COLUMNS
# At line 92 RHS
# At line 121 BOUNDS
# At line 124 ENDATA
# Problem MODEL has 28 rows, 2 columns and 56 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 19 (-9) rows, 2 (0) columns and 38 (-18) elements
# 0  Obj -0 Dual inf 6.110998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 6.110998 (2) w.o. free dual inf (0)
# 3  Obj 1.53825
# Optimal - objective value 1.53825
# After Postsolve, objective 1.53825, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1.53825 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/08a56b6aded7426f89b445f62dbabe7f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/08a56b6aded7426f89b445f62dbabe7f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 208 COLUMNS
# At line 617 RHS
# At line 821 BOUNDS
# At line 824 ENDATA
# Problem MODEL has 203 rows, 2 columns and 406 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 32 (-171) rows, 2 (0) columns and 64 (-342) elements
# 0  Obj -0 Dual inf 43.863998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 43.863998 (2) w.o. free dual inf (0)
# 3  Obj 9.9
# Optimal - objective value 9.9
# After Postsolve, objective 9.9, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 9.9 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8c4ed6080656444a9df603f4fcb87928-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/8c4ed6080656444a9df603f4fcb87928-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 320 RHS
# At line 425 BOUNDS
# At line 428 ENDATA
# Problem MODEL has 104 rows, 2 columns and 208 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 30 (-74) rows, 2 (0) columns and 60 (-148) elements
# 0  Obj -0 Dual inf 23.047998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 23.047998 (2) w.o. free dual inf (0)
# 2  Obj 1.3985882
# Optimal - objective value 1.3985882
# After Postsolve, objective 1.3985882, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1.398588235 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/23a25f5ab1ab4cf397577815e0a74240-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/23a25f5ab1ab4cf397577815e0a74240-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 45 COLUMNS
# At line 128 RHS
# At line 169 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 40 rows, 2 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 20 (-20) rows, 2 (0) columns and 40 (-40) elements
# 0  Obj -0 Dual inf 8.720998 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 8.720998 (2) w.o. free dual inf (0)
# 2  Obj 2.0234167
# Optimal - objective value 2.0234167
# After Postsolve, objective 2.0234167, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 2.023416667 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/randydavila/Documents/Automated-Conjecturing/AI-discovery-in-mathematics-with-TxGraffiti/env/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3ed259341044484fb5d94333a1892f87-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/92/bxgdy2896wdgw0bx9f_1ghhh0000gn/T/3ed259341044484fb5d94333a1892f87-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 85 COLUMNS
# At line 248 RHS
# At line 329 BOUNDS
# At line 332 ENDATA
# Problem MODEL has 80 rows, 2 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 28 (-52) rows, 2 (0) columns and 56 (-104) elements
# 0  Obj -0 Dual inf 17.945165 (2) w.o. free dual inf (0)
# 0  Obj -0 Dual inf 17.945165 (2) w.o. free dual inf (0)
# 3  Obj 3.6862456
# Optimal - objective value 3.6862456
# After Postsolve, objective 3.6862456, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3.686245614 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
# Print the generated conjectures
for i, conj in enumerate(conjectures[:20]):
    print(f"Conjecture {i+1}. ", conj, "\n")
# Out:
# Conjecture 1.  For any vino W, if W is high_sugar, then chlorides(W) >= 1/10*pH(W) + -1/4, with equality on 13 instances.
#
# Conjecture 2.  For any vino W, if W is high_alcohol, then chlorides(W) >= 1/10*sulphates(W) + 0, with equality on 13 instances.
#
# Conjecture 3.  For any vino W, if W is high_alcohol and W is high_pH, then quality(W) <= 5/6*alcohol(W) + -7/4, with equality on 7 instances.
#
# Conjecture 4.  For any vino W, if W is high_acidity and W is high_pH, then chlorides(W) >= -1/10*citric acid(W) + 1/10, with equality on 5 instances.
#
# Conjecture 5.  For any vino W, if W is high_acidity and W is high_pH and W is high_quality, then quality(W) <= 10/3*volatile acidity(W) + 33/5, with equality on 4 instances.
#
# Conjecture 6.  For any vino W, if W is high_acidity and W is high_sugar and W is high_pH, then quality(W) <= 5/9*alcohol(W) + 7/6, with equality on 4 instances.
#
# Conjecture 7.  For any vino W, if W is high_sugar and W is high_alcohol, then quality(W) >= -25/7*pH(W) + 108/7, with equality on 4 instances.
#
# Conjecture 8.  For any vino W, if W is high_sugar and W is high_alcohol and W is high_pH, then quality(W) >= 1*alcohol(W) + -8, with equality on 4 instances.
#
# Conjecture 9.  For any vino W, if W is high_acidity, then quality(W) <= 10/3*citric acid(W) + 67/10, with equality on 3 instances.
#
# Conjecture 10.  For any vino W, if W is high_acidity and W is high_sugar, then quality(W) <= 25/9*citric acid(W) + 27/4, with equality on 3 instances.
#
# Conjecture 11.  For any vino W, if W is high_sugar and W is high_pH, then quality(W) <= 50/9*sulphates(W) + 35/9, with equality on 3 instances.
#
# Conjecture 12.  For any vino W, if W is high_acidity and W is high_pH, then quality(W) <= 2/3*alcohol(W) + 1/5, with equality on 3 instances.
#
# Conjecture 13.  For any vino W, if W is high_acidity and W is high_sugar and W is high_pH, then volatile acidity(W) >= -2/3*pH(W) + 5/2, with equality on 3 instances.
#
# Conjecture 14.  For any vino W, if W is high_sugar and W is high_pH and W is high_quality, then chlorides(W) <= -1/5*sulphates(W) + 1/4, with equality on 3 instances.
#
# Conjecture 15.  For any vino W, if W is high_sugar and W is high_alcohol and W is high_pH, then quality(W) >= -1*fixed acidity(W) + 52/5, with equality on 2 instances.
#
# Conjecture 16.  For any vino W, if W is high_alcohol, then quality(W) >= 19/10*citric acid(W) + 3, with equality on 2 instances.
#
# Conjecture 17.  For any vino W, if W is high_acidity and W is high_alcohol, then quality(W) >= -1/2*residual sugar(W) + 47/10, with equality on 2 instances.
#
# Conjecture 18.  For any vino W, if W is high_acidity and W is high_alcohol and W is high_pH, then quality(W) >= -5/6*residual sugar(W) + 35/6, with equality on 2 instances.
#
# Conjecture 19.  For any vino W, if W is high_acidity and W is high_sugar and W is high_pH, then quality(W) >= -500/7*chlorides(W) + 9, with equality on 2 instances.
#
# Conjecture 20.  For any vino W, if W is high_alcohol and W is high_pH, then quality(W) >= -25/4*pH(W) + 99/4, with equality on 2 instances.
